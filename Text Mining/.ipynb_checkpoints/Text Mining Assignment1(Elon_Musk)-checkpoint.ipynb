# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import spacy
from nltk.corpus import stopwords

# %% [markdown]
# # Imporiting Words List to be used

# %% [markdown]
# # Positive word List

# %%
pos=pd.read_csv('positive-words.txt',sep='\n',  encoding='cp1252',header=None)
pos.iloc[30:40,:]
# Out:
#                                                     0
# 30  ;       mistakes. They are included as these m...
# 31       ;       frequently in social media content.
# 32                                                  ;
# 33  ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;...
# 34                                                 a+
# 35                                             abound
# 36                                            abounds
# 37                                          abundance
# 38                                           abundant
# 39                                         accessable

# %%
pos[pos[0]=='a+'].index.values
# Out:
# array([34], dtype=int64)

# %%
pos.drop(range(0,35),axis=0,inplace=True)
pos.reset_index(inplace=True)

# %%
pos.drop(labels=['index'],axis=1,inplace=True)
pos.head()
# Out:
#             0
# 0      abound
# 1     abounds
# 2   abundance
# 3    abundant
# 4  accessable

# %%
pos['Value']=np.ones(shape=(pos.shape[0]),dtype=int)

# %% [markdown]
# pos

# %% [markdown]
# # Negative Words List

# %%
neg=pd.read_csv('negative-words.txt',sep='\n',  encoding='cp1252',header=None , )
neg.head(5)
# Out:
#                                                    0
# 0  ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;...
# 1                                                 ;
# 2                        ; Opinion Lexicon: Negative
# 3                                                  ;
# 4  ; This file contains a list of NEGATIVE opinio...

# %%
neg[neg[0]=='2-faces'].index.values
# Out:
# array([35], dtype=int64)

# %%
neg.drop(range(0,36),axis=0,inplace=True)
neg.reset_index(inplace=True)

# %%
neg.drop(labels=['index'],axis=1,inplace=True)
neg.head()
# Out:
#             0
# 0    abnormal
# 1     abolish
# 2  abominable
# 3  abominably
# 4   abominate

# %%
neg['Value']=[-1 for i in range(0,neg.shape[0])]

# %%
neg
# Out:
#                0  Value
# 0       abnormal     -1
# 1        abolish     -1
# 2     abominable     -1
# 3     abominably     -1
# 4      abominate     -1
# ...          ...    ...
# 4776        zaps     -1
# 4777      zealot     -1
# 4778     zealous     -1
# 4779   zealously     -1
# 4780      zombie     -1
#
# [4781 rows x 2 columns]

# %% [markdown]
# # List Combine

# %%
all_words = neg.append(pos)
all_words
# Out:
#                0  Value
# 0       abnormal     -1
# 1        abolish     -1
# 2     abominable     -1
# 3     abominably     -1
# 4      abominate     -1
# ...          ...    ...
# 2000    youthful      1
# 2001        zeal      1
# 2002      zenith      1
# 2003        zest      1
# 2004       zippy      1
#
# [6786 rows x 2 columns]

# %% [markdown]
# # Stop Words

# %%
stop1=stopwords.words('english')
list(stop1)
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
stop2=pd.read_csv('stop.txt',sep='\n',  encoding='cp1252',header=None)
stop2=np.array(stop2).flatten()
stop2=list(stop2)
stop2
# Out:
# ['a',
#  "a's",
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  "aren't",
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'both',
#  'brief',
#  'but',
#  'by',
#  'c',
#  "c'mon",
#  "c's",
#  'came',
#  'can',
#  "can't",
#  'cannot',
#  'cant',
#  'cause',
#  'causes',
#  'certain',
#  'certainly',
#  'changes',
#  'clearly',
#  'co',
#  'com',
#  'come',
#  'comes',
#  'concerning',
#  'consequently',
#  'consider',
#  'considering',
#  'contain',
#  'containing',
#  'contains',
#  'corresponding',
#  'could',
#  "couldn't",
#  'course',
#  'currently',
#  'd',
#  'definitely',
#  'described',
#  'despite',
#  'did',
#  "didn't",
#  'different',
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'done',
#  'down',
#  'downwards',
#  'during',
#  'e',
#  'each',
#  'edu',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'entirely',
#  'especially',
#  'et',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'exactly',
#  'example',
#  'except',
#  'f',
#  'far',
#  'few',
#  'fifth',
#  'first',
#  'five',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'former',
#  'formerly',
#  'forth',
#  'four',
#  'from',
#  'further',
#  'furthermore',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'given',
#  'gives',
#  'go',
#  'goes',
#  'going',
#  'gone',
#  'got',
#  'gotten',
#  'greetings',
#  'h',
#  'had',
#  "hadn't",
#  'happens',
#  'hardly',
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he's",
#  'hello',
#  'help',
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hi',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hopefully',
#  'how',
#  'howbeit',
#  'however',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'ie',
#  'if',
#  'ignored',
#  'immediate',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'inner',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'is',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'keep',
#  'keeps',
#  'kept',
#  'know',
#  'knows',
#  'known',
#  'l',
#  'last',
#  'lately',
#  'later',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'lest',
#  'let',
#  "let's",
#  'like',
#  'liked',
#  'likely',
#  'little',
#  'look',
#  'looking',
#  'looks',
#  'ltd',
#  'm',
#  'mainly',
#  'many',
#  'may',
#  'maybe',
#  'me',
#  'mean',
#  'meanwhile',
#  'merely',
#  'might',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'must',
#  'my',
#  'myself',
#  'n',
#  'name',
#  'namely',
#  'nd',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needs',
#  'neither',
#  'never',
#  'nevertheless',
#  'new',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'non',
#  'none',
#  'noone',
#  'nor',
#  'normally',
#  'not',
#  'nothing',
#  'novel',
#  'now',
#  'nowhere',
#  'o',
#  'obviously',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'outside',
#  'over',
#  'overall',
#  'own',
#  'p',
#  'particular',
#  'particularly',
#  'per',
#  'perhaps',
#  'placed',
#  'please',
#  'plus',
#  'possible',
#  'presumably',
#  'probably',
#  'provides',
#  'q',
#  'que',
#  'quite',
#  'qv',
#  'r',
#  'rather',
#  'rd',
#  're',
#  'really',
#  'reasonably',
#  'regarding',
#  'regardless',
#  'regards',
#  'relatively',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'same',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'second',
#  'secondly',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'seen',
#  'self',
#  'selves',
#  'sensible',
#  'sent',
#  'serious',
#  'seriously',
#  'seven',
#  'several',
#  'shall',
#  'she',
#  'should',
#  "shouldn't",
#  'since',
#  'six',
#  'so',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'soon',
#  'sorry',
#  'specified',
#  'specify',
#  'specifying',
#  'still',
#  'sub',
#  'such',
#  'sup',
#  'sure',
#  't',
#  "t's",
#  'take',
#  'taken',
#  'tell',
#  'tends',
#  'th',
#  'than',
#  'thank',
#  'thanks',
#  'thanx',
#  'that',
#  "that's",
#  'thats',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  "there's",
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'theres',
#  'thereupon',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'think',
#  'third',
#  'this',
#  'thorough',
#  'thoroughly',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'took',
#  'toward',
#  'towards',
#  'tried',
#  'tries',
#  'truly',
#  'try',
#  'trying',
#  'twice',
#  'two',
#  'u',
#  'un',
#  'under',
#  'unfortunately',
#  'unless',
#  'unlikely',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'useful',
#  'uses',
#  'using',
#  'usually',
#  'uucp',
#  'v',
#  'value',
#  'various',
#  'very',
#  'via',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'wants',
#  'was',
#  "wasn't",
#  'way',
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'welcome',
#  'well',
#  'went',
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  "where's",
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  "who's",
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'willing',
#  'wish',
#  'with',
#  'within',
#  'without',
#  "won't",
#  'wonder',
#  'would',
#  'would',
#  "wouldn't",
#  'x',
#  'y',
#  'yes',
#  'yet',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zero']

# %%
stop=stop1+stop2
print(len(stop))
stop3=set(stop)
print(len(stop3))
# Out:
# 750
# 599

# %% [markdown]
# stop=stop.append(stopwords.words('english')) print(len(stop)) stop=np.array(stop).flatten() stop

# %% [markdown]
# # Tweet list

# %%
df=pd.read_csv('Elon_musk.csv', encoding='cp1252')

# %%
df.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                             @kunalb11 I’m an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
df.rename(columns={'Unnamed: 0': 'Index'},inplace=True)

# %%
df.drop(labels=['Index'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1999, 1)

# %% [markdown]
# # Text Preprocessing

# %%
from nltk.stem import WordNetLemmatizer
wnl=WordNetLemmatizer()

# %%
text=df['Text']

# %%
import re

# %%
X=[]
for i in range(len(text)):
    sent=text[i].strip()
    sent=re.sub(r'[^a-zA-z]',' ',text[i])
    sent=re.sub('_',' ',sent)
    sent=sent.lower()
    words=nltk.word_tokenize(sent)
    sent=[wnl.lemmatize(word) for word in words if not word in stop3]
    sent=' '.join(sent)
    X.append(sent)

# %%
X
# Out:
# ['kunalb alien',
#  'id aa carmack ray tracing cyberpunk hdr level',
#  'joerogan spotify great interview',
#  'gtera doge underestimated',
#  'teslacn congratulation tesla china amazing execution year',
#  'happy year ox http wfkmyu oj',
#  'frodo underdoge thought fail http zgxjfdzzrm',
#  'owensparks flcnhvy anonyx haha',
#  'flcnhvy anonyx tweet represent real world time allocation',
#  'entertaining outcome',
#  'givedirectly',
#  'agree clubhouse kanyewest',
#  'http rwe uhsts',
#  'geoffkeighley unrealengine real',
#  'bought dogecoin lil toddler hodler',
#  'joshmanmode issue sentencing bit high',
#  'freewalletorg fixing',
#  'freewalletorg unlock account',
#  'astrojordy',
#  'true power haha http fc uhqsd',
#  'freewalletorg crypto wallet give private key avoided cost',
#  'freewalletorg app suck',
#  'rt spacex nasa selected falcon heavy launch element lunar gateway mission http pwt',
#  'ajtourville',
#  'blkmdl rationaletienne adamklotz predict cash flow starlink ipo',
#  'rationaletienne adamklotz starlink staggeringly difficult technical amp economic endeavor http ac skqx',
#  'rationaletienne adamklotz spacex pas deep chasm negative cash flow year http hdjl',
#  'id aa carmack lowest cost ton carbon sequestered net product made scalable http xmyi qwsgw',
#  'adamklotz meant price country difference tax amp shipping',
#  'tobyliiiiiiiiii intended earth idea apply mar',
#  'cryptoshrikar coindesk tesla dan palmer',
#  'xprize team manage carbon capture prize http fsw ianl',
#  'sruhle tesla receives stock comp stock option table missing',
#  'back work',
#  'capybarasurfer mattwallace bit high',
#  'itsallrisky doge appears inflationary meaningfully fixed coin unit time http uh rarc',
#  'michaelgalanin kevinmgill wow',
#  'erdayastronaut michaelhodapp orbital launch tower stack raptor orbit booster improve ship amp booster mass',
#  'michaelhodapp back work tonight',
#  'ogecoin instructional video http ueeocofctb',
#  'people spoken http ovmztgo',
#  'nivetha lexfridman cute',
#  'univercurious extremely misleading image reflect true time cost people rain amp pain',
#  'doge',
#  'hodl rainforest',
#  'finally http gf rg qoaf',
#  'itsallrisky fun crypto',
#  'joshroomsburg snoopdogg genesimmons simplicity genius',
#  'astro dogg spacex yup',
#  'jbuttermost dogecoinrich',
#  'wapodavenport true',
#  'dogecoinrich',
#  'flcnhvy astrojordy easy decade intense work note email text',
#  'astrojordy',
#  'lesson learned',
#  'earth mar',
#  'time story tesla amp spacex',
#  'theonion read thebabylonbee great',
#  'kingdom http je ei hmv',
#  'dumdin grimezsz heard year',
#  'grimezsz dogecake',
#  'yolt http cnof yjpf',
#  'kristennetten damian',
#  'kristennetten yeah',
#  'owensparks',
#  'great thing restaurant hang stranger sjm',
#  'future currency earth',
#  'redlineshifter scratch',
#  'wow',
#  'rationaletienne',
#  'wonderofscience destiny',
#  'renatakonkoly teslarati woodhaus franz essential',
#  'erdayastronaut josh bickett ajtourville spacex ship landing burn clear solution greate http wikiugkz',
#  'adamklotz erdayastronaut josh bickett ajtourville spacex hot gas maneuvering rcs thruster http vso ioed',
#  'erdayastronaut josh bickett ajtourville spacex higher isp',
#  'erdayastronaut josh bickett ajtourville spacex intuitively turbopump fed raptor mu http lbtg sibuc',
#  'brendan nasaspaceflight',
#  'rt spacex falcon launch nasa spherex mission collect data million galaxy explore',
#  'rt spacex falcon launch starlink satellite orbit mission pad deck http cucbgpnx',
#  'mikko darudevil true',
#  'josh bickett ajtourville erdayastronaut spacex yeah default engine lever arm shut good',
#  'ajtourville erdayastronaut spacex engine min throttle point flameout risk la http thniyssnwn',
#  'adamklotz erdayastronaut spacex',
#  'erdayastronaut spacex foolish start engine amp immediately shut needed land',
#  'meme destroyer short',
#  'commander cruz happen',
#  'sandstorm masterpiece',
#  'madoverlord dumb',
#  'time pull method http whlrdr',
#  'low key loki',
#  'high low doge',
#  'gigachad',
#  'dogecoin people crypto',
#  'ur http kf klxb',
#  'huobiglobal entertaining outcome',
#  'doge',
#  'http vviuzwhodt',
#  'erdayastronaut high sea amp wind',
#  'tough http bey pefpcj',
#  'rt spacex watch falcon launch starlink satellite http bjfjlczwdk http ln reesbw',
#  'twitter',
#  'filled graffiti art',
#  'eiraum',
#  'giga berlin progress http ekpg qcbui',
#  'hamoon neuralink neuralink working super hard ensure implant safety amp close communication http yky llpumd',
#  'rt spacex mission enables access everyday people dream space',
#  'rt spacex announcing commercial astronaut mission orbit earth aboard dragon http mbesvnakad http uklsjffrjk',
#  'worked advanced wearable phone robot skill needed neuralink',
#  'feel weird helping make good version cyberpunk true',
#  'working neuralink short term solve brain spine injury long term human ai symbiosis latte http qrc alads',
#  'http xccokojylt',
#  'clubhouse tonight pm la time',
#  'erdayastronaut tj cooney lrocket spacex felixschlang marcushousegame tom great story experim http teezkiwcmk',
#  'rt commercial crew launch alert nasa spacex targeting earlier april launch crew rotation mi',
#  'erdayastronaut tj cooney lrocket spacex felixschlang marcushousegame big fan methane http mdv vdefyc',
#  'tj cooney lrocket spacex felixschlang marcushousegame sound correct tom deserves lot cre http hdri hfa',
#  'tj cooney lrocket spacex felixschlang marcushousegame tom great amp instrumental developing early vers http ulxtclm',
#  'ercxspace smvllstvrs accelerate unusually fast high important reusable http cprrqj',
#  'dogg teslaownerssv escaping',
#  'thebabylonbee read article',
#  'warm sunny day amp snowy mountain http psyqu',
#  'beautiful day la http escjtbzo',
#  'jaylav yeah dr frankensteen http wdj ujqk',
#  'younesh guy gave talk spacex',
#  'flcnhvy halo',
#  'http pyrcfe xp',
#  'carnage life hope true tesla spacex',
#  'thejackbeyer nasaspaceflight cryoproof install engine',
#  'starship sn amp sn http urtpjn amo',
#  'retrospect inevitable',
#  'rgvaerialphotos great shot',
#  'menieb live sword die sword',
#  'lexfridman entropy',
#  'teslaownerssv gamespot buy amp hold company make good amp produce service love',
#  'engineer feed earth small amp smaller http gtohclgj',
#  'gamespot',
#  'cyberpunk hotfixes literally hotfixes great game',
#  'http kmk pegm',
#  'documentingbtc dollar shorting',
#  'westcoastbill',
#  'johnnacrider iupsychdoctor aoc robinhoodapp shopify great spacex',
#  'ohqwix bnnj bcghvzqxlb',
#  'wimgrommen wsbchairman economy making product amp providing great service matter',
#  'iupsychdoctor aoc robinhoodapp tanstaafl small fee fee make robin http czrhlolyvo',
#  'shorty apologist give respect shorty',
#  'sell house sell car sell stock b sh http vjkf bqbod',
#  'rationaletienne teslavangelist',
#  'delayslater finishing engineering year production start year aiming release candidate desig http bfverxpoqu',
#  'ppathole grimezsz made video',
#  'aoc robinhoodapp absolutely',
#  'nasaspaceflight unlike aircraft division fine faa space division fundamentally broken reg http si axbjbz',
#  'evankaylor nomad',
#  'anbuteau',
#  'esthetic cyberpunk incredible btw interior design',
#  'trevormahlmann spacex major esthetic improvement coming',
#  'teslaownerssv dmc ryan',
#  'dmc ryan roadster part rocket',
#  'dmc ryan lafebra gfilche storage amp easily upgradable',
#  'avalonpenrose http djdzxq maz',
#  'couch investor',
#  'teslanews wholemarsblog yeah month',
#  'wholemarsblog drive prnd stalk stick day annoying back amp shifter',
#  'wholemarsblog stalk car guess drive direction based obstacle see context amp nav map http ehq qy',
#  'avalonpenrose hedge fund short shrubbery',
#  'lafebra gfilche http wwqstaxm',
#  'lafebra gfilche yeah rear screen',
#  'mph trap speed mile mph top speed tire',
#  'production car achieve mph second',
#  'play cyberpunk',
#  'plaid model ship month http hfuptnqipb',
#  'discord corpo',
#  'jason yup wild time discord haha',
#  'http fxqkbce',
#  'andycolt waiting faa review',
#  'gamestonk http rztkdzaewj',
#  'labpadre passed initial pressure test',
#  'adamhoov',
#  'ppathole http cffwac',
#  'bought hand knit wool marvin martian helm dog',
#  'http gpcvjibtlm',
#  'kinda love etsy',
#  'thesheetztweetz serve public hamstring starlink today amazon satellite system http snigkxdxfp',
#  'nextspaceflight hoping faa approval test flight tomorrow afternoon',
#  'wholemarsblog entire stack data collection labeling amp inference surround video http sqjkn',
#  'flcnhvy wholemarsblog crazy turn fsd',
#  'wholemarsblog tesla steadily moving nns camera surround video enable superhuman driving',
#  'naval [ tyranny ] road hell paved bad intention',
#  'levine catchy http au myf rn',
#  'megaconstellati aviation intel jetcitystar larrypress sat launched year laser link http ceofli lzm',
#  'megaconstellati aviation intel jetcitystar larrypress yup',
#  'teslagong teslaownerssv cleantechnica hope',
#  'tesmanian laser link satellite ground station needed pole',
#  'teslaownerssv cleantechnica version confusion fsd separate version number rest car',
#  'cleantechnica surprise tesla ai hardware amp software waymo money',
#  'ricguccio teslaownerssv float',
#  'flcnhvy boringcompany fallout themed opening party vega loop happening allowed',
#  'alex benton boringcompany',
#  'vega boringcompany tunnel yesterday boy http tlfouiedfm',
#  'ppathole spacex laser',
#  'rt spacex spacex rideshare offering increased access space small satellite operator seeking reliable affordable rid',
#  'rt spacex falcon stage landed love droneship http gwwllixdg',
#  'rt spacex liftoff http j zvm rh',
#  'codewisdom af',
#  'teslascope switching fsd version numbering distinguish major amp minor update http qmhipv zqs',
#  'nasaspaceflight early week',
#  'rt spacex due unfavorable weather standing today launch team continue countdown seco',
#  'arstechnica sciguyspace company depending mission scru http gby nacrsn',
#  'launching small satellite wide range customer tomorrow excited offering low cost access http qduh',
#  'gerberkawasaki part solution require lot fresh water amp land http fwxsmo',
#  'erdayastronaut spacex sn http kwtvwm mbn',
#  'erdayastronaut good path fully renewable rocket energy solves part problem longer chain hyd http xugrzqijzx',
#  'detail week',
#  'donating prize carbon capture technology',
#  'kristennetten spacex eliburton evafoxu janeidyeve austinbarnard elonsbrain jason patterson astrojordy renatakonkoly pretty',
#  'elonsworld tesla spacex neuralink boringcompany eashanmisra civilization gr http siar ifvwc',
#  'laurenrow evafoxu renatakonkoly sarapolak cz seanmmitchell delayslater elonsworld johnnacrider http vv tthkr',
#  'teslatino tesla absolutely rock',
#  'rt spacex falcon launch starlink orbit eighth launch landing booster http zyj zddfql',
#  'kellyreid rate limiting part process cell production constantly changing',
#  'francissuarez cityofmiami car amp truck stuck traffic generate megaton toxic gas amp particulate http jcqiacxjno',
#  'rationaletienne owensparks tesla giant casting machine literally make full size car http chgqmaiyts',
#  'lexfridman tegmark tegmark exceptionally smart amp good human',
#  'owensparks manufacturing technology ultra high volume industry food amp beverage medical syrinx amp toy',
#  'battery cell production fundamental rate limiter slowing sustainable energy future important pr http ybabezxcv',
#  'ferragu question fsd viewed valuable trade',
#  'tobyliiiiiiiiii erdayastronaut',
#  'erdayastronaut glad',
#  'virgin orbit congratulation',
#  'teslaownerssv good',
#  'mrbeastyt whistle',
#  'dmc ryan tesla cybertruck garage',
#  'dmc ryan tesla awesome',
#  'owenshift good point',
#  'signalapp server side code',
#  'wikipedia happy birthday wikipedia glad exist',
#  'theonion guess watching cobra kai',
#  'superclusterhq ki fallout texas',
#  'breedlove benmezrich chuck norris divide',
#  'cerberu breedlove benmezrich good point',
#  'breedlove benmezrich thing call money information system labor allocation actuall http jz zmqgbo',
#  'monty python amazing http ujq iwt',
#  'rationaletienne tobyliiiiiiiiii erdayastronaut twist knife show',
#  'tobyliiiiiiiiii erdayastronaut wise',
#  'erdayastronaut making major improvement ease engine swap hour',
#  'ppathole johnkrausphotos spacex engine slight repair switched',
#  'johnkrausphotos spacex nice shot',
#  'realomarabdalah high school internship apply college',
#  'skorusark prototype easy volume production hard positive cash flow excruciating',
#  'tesla physic',
#  'rt spacex splashdown dragon confirmed completing spacex st space station resupply mission return cargo resupp',
#  'erdayastronaut detanking amp inspection good progress hop amp mar goal',
#  'static fire completed amp ruds',
#  'justpaulinelol erdayastronaut spacex wow lot happened year',
#  'officialjlipper fair haha',
#  'http ho ygxas',
#  'nasaspaceflight sea shanty tiktok take level actual pirate ship',
#  'connectdotstoo',
#  'today spacex practicing starship engine start ship held massive pin engine fir http qtiiwlxxpl',
#  'tesmanian promised',
#  'legalize comedy',
#  'lvladimirovbg steal logo amp sue',
#  'arstechnica sciguyspace people mar appreciated',
#  'spacex space station day camera show star field background',
#  'rt spacex separation confirmed dragon performing departure burn move space station http ohwvnxj',
#  'lexfridman suicide double homicide http mvwgps uqe',
#  'lexfridman absolutely',
#  'hey yeah queen gon na make http lrqdirbiyd',
#  'theoldmanpar djsnm machinepix hate true',
#  'machinepix robot future coming',
#  'wonderofscience physicsj km millisecond time faster',
#  'http tkkruvgbth http ocy gfryvn',
#  'iamdevloper http bkkeiiicye',
#  'mu protec yoda http dvhg ntku',
#  'roscosmos',
#  'rationaletienne thebabylonbee important distinction',
#  'valaafshar amp increasing rapidly',
#  'codingmark flcnhvy',
#  'archillect imagined',
#  'skorusark factory product',
#  'austinteslaclub thebabylonbee commenting signalapp',
#  'ppathole bought replacement glass junkyard great place spare part',
#  'thebabylonbee lot people super unhappy west coast high tech de facto arbiter free speech',
#  'alexandersibert signalapp donated signal year ago donate',
#  'benmezrich primarily advance sustainable energy amp extending life consciousness http vybfavhkys',
#  'song wooseok gerberkawasaki benmezrich',
#  'ragazaga spacepadreisle tesla ai day year',
#  'spacepadreisle prancing pony',
#  'boredelonmusk',
#  'erigganewmoney',
#  'mayemusk true',
#  'glenn woketopiansa long',
#  'woketopiansa yeah optimistic',
#  'year son saxon feel good year agree make',
#  'erdayastronaut spacex thinking spacex boca hold fun party give tour community time time',
#  'erdayastronaut spacex super support public space production amp launch site http wmqwct wfh',
#  'christo sean erdayastronaut spacex',
#  'sean erdayastronaut spacex catapult high air amp land roof base jumping parachute travel',
#  'erdayastronaut spacex restaurant spacex building futuristic bar top http umtgsaoi',
#  'techreview increase fun',
#  'benmezrich',
#  'tonychomrmagic teslaenergy tesla solar roof installation',
#  'demigod day',
#  'ppathole engineer feed large solar field reactor needed po http ph plnam',
#  'engineer feed sick beat http pbsgffzrp',
#  'flcnhvy dozen primary decision maker technically',
#  'erdayastronaut lexfridman option verification public ascribe credibilit http ju wemvsjg',
#  'launch underway http wbk zz fqx',
#  'btw critical feedback super appreciated way donate money make difference harder',
#  'eugenelee engineer feed yup',
#  'engineer feed indirectly electric rocket electricity convert gt ch http fqzotwqt',
#  'engineer feed orbit space photon emission powered matter antimatter annihila http po opqn',
#  'teslarati residentsponge hard make vehicle',
#  'thfromourstar playing long game',
#  'ashleevance true',
#  'id aa carmack hope wing work moon def mar runway',
#  'ericrweinstein hamiltonians potential langrangians play',
#  'http ja mre',
#  'teslaownerssv back work',
#  'teslaownerssv strange',
#  'signal',
#  'thehackersnews ya reminds timeless classic http gq wayotir',
#  'univercurious fast water tiny rock',
#  'flcnhvy occam razor',
#  'external observer participant',
#  'entertaining outcome',
#  'ppathole dumb dumber great movie tho',
#  'called domino effect http qpbew rvm',
#  'dtrford austinbarnard alexsvanart ercxspace spceenthusiast spacexvision tomdixondesign spacex http e garryvs',
#  'large footprint flat range story tall',
#  'snow falling giga berlin http etxmtyp hg',
#  'rgvaerialphotos spacex',
#  'gfilche',
#  'flcnhvy tesla responsible personal amp professional pain life combined worth',
#  'proud tesla team achieving major milestone start tesla thought optimistica http wlybpkmzj',
#  'rt tesla produced delivered half million car huge made http vz rmhd',
#  'newscientist um giant fusion reactor sky work maintenance',
#  'comma ai tesla full driving work safety level average driver year http jmabjuqfdf',
#  'ppathole dojo needed make driving safer human driver aut http dyy rmhgil',
#  'ignore heading',
#  'great interview mathias pfner http ewnahc ch',
#  'jack greatest gatsby',
#  'flcnhvy inspired ballet',
#  'smvllstvrs ercxspace rocket motion primarily vertical top open',
#  'jack make roaring',
#  'erdayastronaut lump',
#  'erdayastronaut flcnhvy ercxspace production hard prototype easy building starship create http xjlljpljbp',
#  'icannot aloysiusfekete rationaletienne biogirl ercxspace',
#  'rexchapman haha',
#  'erdayastronaut flcnhvy ercxspace sn press ch header tank helium long term solution debate http kawwol jg',
#  'flabellina rationaletienne biogirl ercxspace',
#  'rationaletienne biogirl ercxspace leg work part part step step',
#  'flcnhvy ercxspace',
#  'flcnhvy ercxspace save mass amp cost leg amp enables repositioning booster launch mount rea http jwdcjarymj',
#  'ercxspace catch super heavy booster launch tower arm grid fin load',
#  'snake head dog undivided attention winder head ostrich gliding nonchalant http dtpmdm tqp',
#  'tesmanian odd opposition group bmw home state baveria brande http dyvli cx',
#  'tesmanian opposition progress',
#  'harsimranbansal literally',
#  'tobyliiiiiiiiii real',
#  'destiny destiny escaping',
#  'tesla car delivered final day year month full driving option http ppaereeo',
#  'spacenews mark dankberg action wack dank',
#  'reza zadeh',
#  'ashleevance westworld',
#  'kingdom show great',
#  'jayson absolutely text amp visualization add voice',
#  'sfs central cheese made cake',
#  'karpathy love deep trouble',
#  'made cake http omacmyqawx',
#  'chicago glenn true haha',
#  'weird game http mrvvzmekg',
#  'cgi http voive vpr',
#  'bensullins ui overhaul',
#  'maldivawow codingmark tesla incremental improvement production codebase fsd build http puoramgo',
#  'spacenews starlink pose hazard viasat profit stop sneaky move charlie ergen',
#  'entertainment critical car drive',
#  'kimpaquette meeting larry ellison seek advice back working tesla end quarter tomorrow',
#  'richierichhhhh absolutely',
#  'tesla car gaming autonomous world',
#  'ppathole wsj absolutely',
#  'tesmanian taste future',
#  'playing polytopia tesla great game multiplayer online version coming',
#  'wsj focus making product amp service people love total economic pie bigger en http qe jcezytq',
#  'thatdesignguy siphiw moosuraj tesla roughly part tesla roadster unique pro http yb cmrb',
#  'laurenrow karpathy',
#  'engineer feed important',
#  'teslaownerssv lexfridman service check',
#  'teslaownerssv lexfridman install external speaker earlier car',
#  'gunmtlm lexfridman year',
#  'lexfridman good point',
#  'conexionspacial spacecoast stve nasaspaceflight interesting',
#  'flcnhvy liz great interview',
#  'spacecoast stve nasaspaceflight falcon successful orbital launch majority pa http pmgu vhqez',
#  'karpathy vaccine start capable theory curing turn medicine http uruvc qf',
#  'jgrano teslatruckclub jeremyjudkins jpuconn jchybow dirtytesla',
#  'teslatruckclub jeremyjudkins jpuconn jchybow dirtytesla offer multiple display option',
#  'ivanescobosa erdayastronaut teslaownerssv revision needed beta',
#  'erdayastronaut teslaownerssv',
#  'erdayastronaut teslaownerssv haha',
#  'kkvr tesla adri teslaownerssv subtle important difference amp canada traffic rule bu http xzx ppvl',
#  'tesla adri teslaownerssv',
#  'teslaownerssv match traffic speed setting',
#  'stevewoz',
#  'flcnhvy extrachars step direction',
#  'arm arm car pedestrian speaker http hkza ohe',
#  'westcoastbill writing cobra kai sick',
#  'afloathickory haha save nightmare short',
#  'extrachars upload custom music sound',
#  'jgrano pedestrian speaker needed external sound generator actual horn',
#  'change horn sound holiday jingle latest tesla software update',
#  'merry christmas amp happy holiday http uk nspwr',
#  'tesmanian great game',
#  'harsimranbansal heydave make sense starlink public revenue growth predictable',
#  'heydave engineering design amp general company operation absorb vast majority mind amp fundamental li http vxv ghumbd',
#  'elonsworld real futurist lexfridman',
#  'flcnhvy marcushousegame month',
#  'marcushousegame coming',
#  'olhzn minor',
#  'trevormahlmann yeah',
#  'story rocket turn engine amp controlled fall http hcrgyx rn',
#  'erdayastronaut yup ironing bug',
#  'tesla owner taking delivery final day year support super appreciated',
#  'deepmind nature frictionless ai possibly wrong',
#  'heydave good idea',
#  'wintonark darkest day model program reached tim cook discus possibility http optz urne',
#  'wintonark strange true tesla iron phosphate medium range car made shanghai facto http milwsilvrt',
#  'archillect sparta reply macedon',
#  'lizclaman tesla foxbusiness clamancountdown liz',
#  'worked hard make tesla successful heart',
#  'teslaownerssv',
#  'kristennetten twisted affair end',
#  'mkbhd kind low key tesla supercharger made accessible electric car',
#  'rt spacex photo yesterday launch landing http whx bx http ojfysuaxo',
#  'michael saylor large transaction',
#  'fe love crazy ppl fe',
#  'bizzzzzyd point sigh',
#  'pcgamer great game',
#  'flcnhvy pretty main college hanging pseudo intellectual conversation amp http ybscm',
#  'comment stay meme',
#  'padgeuk absolutely release fsd subscription early year',
#  'word doge',
#  'bitcoin b fiat money',
#  'hajek miloslav great nail amp lipstick',
#  'mightytesla kristennetten lauren kalo sawyermerritt jasondebolt codingmark delayslater babytesla http dvwzgtppda',
#  'http ebojgshvrq',
#  'callowaytech sound',
#  'lord edge',
#  'xdreamcoding frank thelen nice branding',
#  'kidding safe word',
#  'bitcoin safe word',
#  'rt spacex falcon stage landed landing zone http mr goc',
#  'rt spacex liftoff http ag rar qnp',
#  'spacex standing today inspect rocket launching tomorrow',
#  'spacex pressure slightly high upper stage liquid oxygen tank review underway',
#  'tesla mania hoping back month',
#  'nytimes impressive mission china',
#  'spacex launch coming',
#  'teslaownerssv astonmartin tesla grumpy point',
#  'teslaownerssv absurdly good tesla ai autopilot engineering awesome great ai ther http muheapoq',
#  'star light star bright http cetazsxco',
#  'teslarati ericralph incorrect',
#  'thebabylonbee',
#  'pcgamer visually stunning amp playability good',
#  'pcgamer shirt armor kevlar chest plate make sense absence magic http iydkttvsqk',
#  'cleantechnica umm http jtg ercy',
#  'cleantechnica absolutely support trans pronoun esthetic nightmare',
#  'erdayastronaut flightclubio raptor max thrust ship blown altit http ikcrzpyxtr',
#  'erdayastronaut flightclubio fully loaded slow ship crazy high engine',
#  'picot john cyberpunkgame good great game imo improving mere surface detail woul http zm sz cbzg',
#  'truth tesla tesmanian slightly confident essential view output time http rkfvjvotse',
#  'tesmanian dankesch brandenburg und gr nheide',
#  'austinbarnard lrocket hope future pas',
#  'tesmanian giga berlin brandenburg structural pack architecture world http wesafntz',
#  'dota funny cyberpunkgame original deus incredible human revolution great',
#  'cyberpunkgame objective reality impossible run advanced game hardware http zo qsu wt',
#  'rt spacex starship landing flip maneuver http qud hwz cx',
#  'theonion thebabylonbee',
#  'ascent heaven http oggsw yrz',
#  'engineer feed',
#  'ppathole cyberpunkgame yeah briefly pretty good picked nomad start slow pick http nllipnbmxr',
#  'zwiebelbach menieb cyberpunkgame http aayypcpp',
#  'hehe http sklmil oxt',
#  'cyberpunkgame http rhksb xqr',
#  'cyberpunkgame http kmg qf',
#  'http sdmxkbhdzd',
#  'http qbnt dused',
#  'rt spacex falcon launch sxm orbit completing spacex launch year http zrur ewnlv',
#  'quantamagazine init void',
#  'ppathole ercxspace spacex cooling haha',
#  'ppathole ercxspace spacex soft spot heart transpiration cooking theory http sschdkfad',
#  'ercxspace spacex ship leeward side bare metal windward black hexagonal heat shield tile',
#  'rt pockn cg wait elonmusk spacex spacexstarship http ynetmywfvg',
#  'conexionspacial pockn cg',
#  'spacepadreisle spacex agreed preserved memory sn',
#  'rt spacex photo starship sn flight test http whx bx http ozlyf qrf',
#  'nasaspaceflight bocachicagal woohoo',
#  'erdayastronaut spacex sn great reaching apogee great controlling putting http xwm fxmx',
#  'south texas support gateway mar',
#  'life universe http zczinfc',
#  'erdayastronaut yeah engine great',
#  'mar',
#  'fuel header tank pressure low landing burn causing touchdown velocity high amp rud http wgjvdsahmf',
#  'successful ascent switchover header tank amp precise flap control landing point http iiraiesg',
#  'thebabylonbee',
#  'wonderofscience orbital space fastest travel long distance earth',
#  'spacex space station called space station moving earth time spee http vyvivrtzsa',
#  'rt spacex time lapse dragon approach dragon docked space station http jbmc',
#  'long orifice alien message decrypted',
#  'spacex chance completing mission objective',
#  'spacex flying tomorrow',
#  'nasaspaceflight yup',
#  'rt nasa success pm spacex upgraded dragon cargo spacecraft autonomously docked space station st',
#  'pad south texas http rcyoxxptc',
#  'rt space station station spacex dragon orbital night period pm docking crewdragon',
#  'space station spacex wow station amazing',
#  'rt nasa good morning earthling fe journey continues watch nasa spacex cargo resupply mission dock space statio',
#  'nasaspaceflight knock knock singing telegram',
#  'lexfridman carrying symbiotic bacteria trillion cell',
#  'adamklotz lexfridman',
#  'lexfridman mobile cell colony',
#  '',
#  'rt spacex tracking footage helicopter today falcon launch lc http ryvzrts',
#  'rt erdayastronaut genuinely magical starship sn person boca chica beautiful quiet serine',
#  'im gespr ch mit mathias pfner http bqa piaonk',
#  'rt spacex dragon separation confirmed spacecraft space station autonomous docking tomorrow approximately',
#  'rt spacex falcon booster landed love droneship http cnl lq',
#  'rt spacex liftoff http pgk cph',
#  'haya jaxa jaxa en congratulation',
#  'haya jaxa congratulation',
#  'rdanglephoto spacex teslarati',
#  'rt boringcompany tunnel rave http jkoiasy',
#  'rationaletienne toilet paper',
#  'watch demolition man',
#  'prometheus unbound',
#  'rt spacex falcon booster supporting mission previously launched nasa astronaut bob behnken doug hurley space sta',
#  'ercxspace spacex nasaspaceflight erdayastronaut marcushousegame felixschlang bad',
#  'theonion beast compared vic',
#  'tesmanian award accepted behalf great people tesla spacex neuralink amp boring',
#  'people science engineering thing rocket scientist roc http w uvcryn',
#  'science discovering essential truth exists universe engineering creating thing http xmqtbrldyp',
#  'justpaulinelol bit cold night',
#  'engineer feed paint make hell difference',
#  'deepmind congrats',
#  'lrocket build spacex memory',
#  'rgvaerialphotos real',
#  'marcushousegame bcart nextspaceflight nasaspaceflight starship leg hardest problem external http csizk sevu',
#  'bcart nextspaceflight nasaspaceflight static fire risky build site clear build site early flight',
#  'nextspaceflight nasaspaceflight static fire tomorrow flight earlier wednesday',
#  'ercxspace spacex landing leg',
#  'eugenelee ppathole karpathy sad news tony great',
#  'ppathole karpathy thought pic thanos haha',
#  'poppa bearq id aa carmack yeah truncate zero amp round',
#  'dburkland id aa carmack wider beta week',
#  'id aa carmack fp important digit truncated feel fp betting training dojo',
#  'id aa carmack int heavy lifting inference work great',
#  'thisisjendoll http lb pksayi',
#  'thisisjendoll http mmg',
#  'happy thanksgiving',
#  'teslaownerssv johneg teslachillmode unplgd mfrunker ccteslaclub month',
#  'johneg teslachillmode unplgd mfrunker ccteslaclub air suspension height amp damping algorithm http opgo vd',
#  'karpathy haha true',
#  'humanoidhistory promise greatly needed',
#  'evafoxu special color roadster original',
#  'rationaletienne thebabylonbee',
#  'thebabylonbee savage',
#  'worldandscience wondered',
#  'life leader launch risk normal http etfp ielrf',
#  'teslatino flcnhvy thesheetztweetz slightly filled',
#  'aholstein flcnhvy thesheetztweetz subject debate',
#  'flcnhvy thesheetztweetz major upgrade slated sn',
#  'flcnhvy thesheetztweetz small improvement similar wiring robust engine mat http ofbmy',
#  'thesheetztweetz sn amp sn',
#  'thesheetztweetz lot thing chance',
#  'good starship sn static fire aiming km ft altitude flight week goal test engin http ojorqnhb',
#  'erdayastronaut marcushousegame start year depends starship progress',
#  'rationaletienne marcushousegame',
#  'starshipfairing marcushousegame bad engine make cargo bay propel http uvultatv',
#  'marcushousegame rapid amp complete rocket reuse low cost propellant orbital refilling amp propellant production http umyur yshy',
#  'erdayastronaut ppathole teslarati teslaroadtrip',
#  'ppathole teslarati teslaroadtrip simply video control biggest game changer cu http nb hl gzlx',
#  'teslarati teslaroadtrip fsd beta coming day improvement significant',
#  'xhnews exciting mission',
#  'vincent tesla wow',
#  'liv boeree yea',
#  'tomorrow flight rocket landing droneship love',
#  'johnnacrider teslaownerssv delayslater',
#  'futurejurvetson flcnhvy true',
#  'rationaletienne heydave philwhln quiet queue product build roadster point',
#  'rationaletienne shycybertruck fate love irony hate hypocrisy',
#  'rt nasa booster separation engine start fairing separation european sentinel michael freilich ocean observing',
#  'icannot heydave',
#  'flcnhvy data center named skynet joke year ago tempting fate',
#  'heydave philwhln tesla vehicle creating amp producing product',
#  'nasaspaceflight largest cast titanium part world heat shielding needed',
#  'landing vandenberg afb california http gccjp',
#  'tobyliiiiiiiiii spacex nasa nasa lsp nasajpl esa side launch http fr aucywco',
#  'tobyliiiiiiiiii spacex nasa nasa lsp nasajpl esa',
#  'philwhln heydave investor tesla good company investing http wduz wnuin',
#  'http ffpvdsqruc',
#  'day ahead http apzngmo',
#  'rt spacex crew view earth dragon flight space station http lqw tympb',
#  'nasaaero lockheedmartin call pointy',
#  'cleantechnica cool',
#  'astro fonseca space station wonderofscience virtualastro moving time speed sound feel',
#  'worldandscience http xajan zr',
#  'vicentes evafoxu ppathole mirojurcevic tashaark space station upgrade',
#  'evafoxu ppathole mirojurcevic tashaark space station human vision margin',
#  'enn nafnlaus mirojurcevic tashaark space station reality strange ghost world radar wavelength http dmgov rcnu',
#  'ppathole mirojurcevic tashaark space station',
#  'mirojurcevic tashaark misperception spacex developed amp continues lidar dragon docking http bwgjlqp',
#  'philippecroizon spacex day fly starship',
#  'peter beck',
#  'hisdirtremoves spacex comment turbopump internal detail roughly ballpark wow roc http srlfg fg',
#  'tashaark clear xpeng problem company china',
#  'isaaclatterell tashaark karpathy andrej awesome talented autopilot http ocngk ey',
#  'spacetouristuk tashaark yeah stole apple code http gy dt pq',
#  'tashaark version software amp nn inference computer',
#  'levie wild time',
#  'rocketlab congrats',
#  'slashdot theonion',
#  'id aa carmack yup',
#  'flcnhvy change part fine',
#  'forbes caution strongly advised spacs',
#  'adamkiotz suvitruf archillect',
#  'suvitruf archillect haha sexy cropping champion time',
#  'tweetmenima teslaownerssv week release good widen beta',
#  'justpaulinelol teslaownerssv rule liquor distribution http kvhlbuee',
#  'teslaownerssv week release special lot fundamental improvement important bug fix amp entire http bv stdwngj',
#  'westcoastbill spacex year amp billion wow',
#  'owensparks flcnhvy tesla safety primary design goal',
#  'ppathole astrojordy flcnhvy fully',
#  'astronomiaum martian decide future',
#  'shifthappends tesla lot brain space spent dealing unit',
#  'astronomiaum terraforming slow relevant lifetime establish human base http uygaae',
#  'ppathole xdreamcoding garyblack intention',
#  'xdreamcoding garyblack http frezwjcwna',
#  'garyblack publicly traded stock tesla',
#  'garyblack wise word bogle point company product amp service point amp thems http encu cblpy',
#  'teslaownerssv astrojordy flcnhvy mild cold bro def cov pc lt mean viral http uysanpqtfi',
#  'astronomiaum life glass dome eventually terraformed support life earth',
#  'astrojordy flcnhvy yeah',
#  'daywalker xd astronomiaum sim obvious haha',
#  'astronomiaum deveras',
#  'flcnhvy case high infectious ct quarantine day test seco http oalvzwcmio',
#  'tobyliiiiiiiiii thing amp wanted',
#  'nichegamer mercy http hoihr',
#  'tesla holiday software release',
#  'staceyr maisie williams',
#  'cobra kai deep cut',
#  'archillect cake amp bite',
#  'nichegamer thing sentience',
#  'deus machine learning http zsyalvczx',
#  'peterrhague designed make life multiplanetary extreme overkill mere earth sector activity http yjltt peeu',
#  'kristennetten royalsociety gave blessing sort groundswell believed http fwk zihfeg',
#  'nullius verba royalsociety',
#  'westcoastbill',
#  'reflexfunds nickidk pcgamer dojo doge',
#  'ppathole erdayastronaut rweb yeah marginal cost launch http rnsj fkdxt',
#  'speculawyer erdayastronaut rweb',
#  'erdayastronaut rweb merlin strong local maximum design kerosene suboptimal fuel matter http joetyskgp',
#  'parstalberg josh bickett icannot erdayastronaut rweb visiting american ah irony',
#  'josh bickett icannot erdayastronaut rweb yeah pcr ct unequivocal lt matter http yjdogokx',
#  'flcnhvy lugg pcgamer making notable wait figurative amp literal dust settle',
#  'icannot erdayastronaut rweb pretty close feel af dayquil frankly http hj thlr',
#  'lugg pcgamer avionics cable moving steel pipe shield amp adding water cooled steel pipe test pad',
#  'lugg pcgamer sec starting engine martyte covering concrete shattered sending blade http vilv yo',
#  'erdayastronaut rweb amazing thing rocket engine blow http euxoocfr',
#  'pcgamer count atom point',
#  'djsnm erdayastronaut charlesnotrumps rweb absolutely production testing rocket engine http tv pixzp',
#  'erdayastronaut charlesnotrumps rweb merlin engine design bad tbh worked http njrepvtc',
#  'billhuang johnnacrider timmerenginerd jack love irony haha',
#  'greenisclutch johnnacrider timmerenginerd jack teslaquila month',
#  'chrisg nsf special permission received stonecutter guild http sw rbm srb',
#  'johnnacrider timmerenginerd jack fate irony',
#  'jack',
#  'trylolli maisie williams http uwerahxuev',
#  'erdayastronaut rweb damn easy spent bit time russian ukrainian engine good',
#  'ppathole michaelmina lab',
#  'rt spacex docking confirmed crew dragon arrived space station',
#  'maisie williams toss bitcoin ur witcher',
#  'kristennetten',
#  'rt nasa enter crew dragon est utc nasa spacex crew astronaut give live tour space',
#  'whatsupfranks michaelmina lab curevac moderna amp tesla make machine curevac kn http kveprq rl',
#  'michaelmina lab creating synthetic mrna cure vaccine future medicine imo turn http yp djawiks',
#  'gaertner anne neuro skeptic dresdentea judith herbers haha',
#  'michaelmina lab great thread',
#  'samtalkstesla symptom past day fatigue chang http eo xb sf',
#  'fe',
#  'launch minute',
#  'flcnhvy yeah cooling channel integrated chamber wall',
#  'propellant abort orbital maneuvering obviates',
#  'dragon hover amp land propulsively parachute maximum safety http mr vfiqwwf',
#  'thruster integrated spacecraft enabling abort capability abort increased safety http krohkor ae',
#  'rt nasa song play ride launch pad launchamerica http vzhxun yie',
#  'rt spacex dragon completed flight space station designed beginning human spaceflight mi',
#  'rt spacex dragon spacecraft flying capable returning significant amount cargo earth priv',
#  'rt spacex spacex custom tailored suit route communication cooling system protect crew event cabin depressu',
#  'rt nasa live ready launchamerica watch coverage nasa spacex crew mission liftoff pm',
#  'rt spacex watch falcon launch crew dragon operational mission space station astronaut board http',
#  'tboneagnoobs',
#  'rt spacex system tonight launch est crew dragon operational mission astronaut boa',
#  'klotzadam ppathole astrojordy erujabidi yeah feel pretty normal symptom week sym http gl mhrqjxy',
#  'ppathole astrojordy erujabidi test lab time day administered rn amp http hajhh la',
#  'ppathole mario livio obv insanely great bad pointless argument',
#  'astronaut launch today http fazzgss',
#  'rt nasa astro soichi message boy girl japan space waiting tumblr spotlight jaxa en astronaut',
#  'rt nasa week nasa spacex crew astronaut arrive nasakennedy ahead launch nasapersevere rover mark day',
#  'rt astro soichi spacex nasa crew finished final dress rehearsal ready saturday launch real dragon',
#  'mario livio kid',
#  'mario livio hell wig collection',
#  'michaelmina lab great lab give people level granular feedback result',
#  'rt michaelmina lab elonmusk great question complex question depends test kn',
#  'worth reading thread curious rona testing http fa kd eba',
#  'stonkmanup michaelmina lab imo blood pressure test number ju http twl dgurmk',
#  'astrojordy erujabidi amp feel regular cold body achy amp cloudy head http ihvpeox',
#  'michaelmina lab opinion ct number cov gene pcr test regarded http emuxlx',
#  'michaelmina lab stendeck',
#  'teslaownerssv cool super cautious expect step forward back lot code merged',
#  'austinbarnard scratch buff',
#  'erujabidi wildly result lab moderate case covid http xlbahahjoj',
#  'whatsupfranks lexfridman npc',
#  'lexfridman ahem',
#  'dmt',
#  'law thermodynamics win break stop playing',
#  'shake fist entropy',
#  'realnattastic big expansion beta program week',
#  'robintosh nunez ppathole interesting thursday night saliva sample back today gene unique cov http tm c otdt',
#  'icannot johnnacrider honey',
#  'slashdot feel',
#  'whatsupfranks bluemoondance stephenking accurate',
#  'bluemoondance stephenking cold symptom ab',
#  'stephenking degree po',
#  'mrsammy pelagicbird max roi rossy heneghan make lot sense hilarious clarify http mlxngcsa',
#  'whatsupfranks number pcr amplification cycle required detect virus rough indicator vir http mn hueq',
#  'mrsammy max roi rossy great reference worth read',
#  'case closed http puyijcadd',
#  'http mwopr kk',
#  'ppathole fwiw lab spoke think accurate dicey amp b talk http wxq yt',
#  'lab spoke cov pcr detection amp gene cycle reliable amp cycle',
#  'rationaletienne ryaneshea note spike protein reliable',
#  'rationaletienne ryaneshea spoke directly testing lab main pcr search gene unique http odvdauo',
#  'ppathole strange',
#  'ryaneshea explanation dramatic decline cold amp flu prevalence prior year http gmlvewwxdp',
#  'ryaneshea lower true prevalence higher false positive number sound obvious http xvabeklh',
#  'ryaneshea http vrpb http xtsukcc tl',
#  'dana morgan',
#  'great hear people lot pcr testing industry approximate false posi http lvc nikql',
#  'clarecraigpath interesting',
#  'john bean dirtytesla interesting',
#  'general population knowledge symptom accuracy sars cov pcr test amp gene http vbiu d uq',
#  'ppathole cleantechnica good pcr test identify cov spike protein heard http vj gaofs',
#  'justpaulinelol cleantechnica mild sniffle amp cough amp slight fever past day symptom nyquil',
#  'cleantechnica technically tested positive negative positive elon musk test negati http ohta',
#  'carousel turn faster',
#  'joeingeneral andrewbogut yup',
#  'ajtourville',
#  'janeidyeve symptom typical cold unusual',
#  'blkmdl happening happening pcr test separate lab result hour',
#  'extremely bogus tested covid time today test back negative cam http zcf',
#  'austinbarnard burst disk worked vehicle appears swap engine',
#  'tobyliiiiiiiiii spacepadreisle austinbarnard melted engine preburner fuel hot gas manifold whatev http elyx pjlg',
#  'austinbarnard lost vehicle pneumatics reason unknown present liquid oxygen header tank pressure risin http szc hnti',
#  'drphiltill',
#  'rt teslarati tesla top list attractive employer engineering student http kknyqlet',
#  'astronaut fly space station sat night cape operational flight crew dragon http uzcgikcikb',
#  'cardoso luck superpower',
#  'rt spacex served sacrificed veteransday http kn fzpj',
#  'rt spacex crew access arm swing place http xaimd nljv',
#  'hiromichimizuno',
#  'kristennetten honor choose work strive ensure company enable http otdwcsk ck',
#  'privilege work people amp respect feel blessed',
#  'rt commercial crew flight readiness review crew mission space station concluded nasa spacex',
#  'rt spacex falcon crew dragon vertical launch complex http hbvuhwv ab',
#  'djsnm davidhuber nickhenning spacex ercxspace neopork bass caspar stanley spacexvision felixschlang',
#  'teslany tesla happy',
#  'samtalkstesla tesla expect important product world financially material tesla',
#  'nickhenning spacex ercxspace neopork bass caspar stanley spacexvision felixschlang entry http ncafknfzlc',
#  'samtalkstesla tesla tesla make rna bioreactor make vaccine cure curevac version http opouohyamu',
#  'rt spacex crew dragon falcon hangar launch complex ahead launching astronaut space station liftoff',
#  'teslatino checking',
#  'pcgamer hope game twist tedium fear canceled',
#  'rt boringcompany rumor austin chalk geologically soil tunneling find austin job avai',
#  'http wnkg',
#  'damn cookie browser setting',
#  'teslaownerssv tesla lot great autopilot ai hardware amp software engineer tesla',
#  'bbctech',
#  'mkbhd vyyyper worth',
#  'mkbhd',
#  'model owner mkbhd',
#  'mkbhd http zlkc fc',
#  'ed spartan tesla nykchannel wait cybertruck',
#  'mkbhd accidental back shortly',
#  'rt tesla supercharger counting http urudyt eui',
#  'erdayastronaut renatakonkoly spacenews hoping change booster design land back launch mount http hprgptt ru',
#  'vasu amyceskridge chip temp sensor amp automatically maintains safe temp',
#  'reganlovetesla renatakonkoly spacenews plate amp tesla day prototy http tgpwej wqa',
#  'amyceskridge neuralink overclock brain transfer processing supercomputer extension yo http nbybbfx',
#  'flcnhvy ppathole cleantechnica rewrote labeling software labeling single phot http mltbdsquty',
#  'ppathole cleantechnica version year',
#  'renatakonkoly spacenews calculation incorrect',
#  'spacenews china understands profound importance reusability era expendable rocket',
#  'cleantechnica fe fe tesla autopilot ai team fe fe',
#  'cleantechnica good explanation essential dynamically occluded object large intersection http ooj pqayhj',
#  'rt archillect http fnqfhr',
#  'phantom opera inside mind',
#  'linustech spacexstarlink spacex',
#  'ppathole problem solver thing high sense urgency care school',
#  'sending resume describe hardest problem solved amp solved',
#  'banner needed hard left',
#  'ppathole fine day simulation',
#  'nereide faraday invented electric motor tesla commutator free phase ac induction motor http cqo rjlrbv',
#  'nereide maxwell amazing recognition tesla motor called faraday http kmcpgk',
#  'ten time',
#  '',
#  'rt spacex deployment gps iii confirmed http fcfjrcwmti',
#  'rt spacex falcon stage land love droneship http hd ibpx',
#  'rt spacex liftoff http li tnml',
#  'linustech spacexstarlink spacex awaiting approval canadian authority',
#  'recruiting ace engineer giga berlin interview person tomorrow site send resume gun tesla',
#  'chad hurley realdonaldtrump kanyewest stop chad',
#  'chad hurley realdonaldtrump kanyewest uh chad wtf',
#  'techamazing einstein great succeed engineering',
#  'jtrevorchapman yeah easy user ocean',
#  'icannot zainraz vincent jonerlichman expect stock rise http tmw phbef',
#  'futurejurvetson ppathole super support steve convertible loan gave month runway http ej iovx',
#  'zainraz vincent jonerlichman closest month model ramp extreme stress amp pa http wuhekj hio',
#  'vincent jonerlichman put money thought fail eithe http bgkez',
#  'jonerlichman funding round completed pm christmas eve hour day investo http umfgjnkoxm',
#  'josh bickett ppathole',
#  'ppathole lowering starlink terminal cost sound pedestrian difficult technical challenge',
#  'itshamzahkhan regulatory approval middle year',
#  'thesheetztweetz take min set future improvement mi http ehbqc fa',
#  'kjell arne flcnhvy canada norway early beta',
#  'enn nafnlaus flcnhvy realize problem current design cybertruck approved europe',
#  'flcnhvy country approval required country individually eu wide approval http zbt qjd',
#  'jason rassett lower latitude state satellite position january',
#  'thousand starlink beta participation invitation week',
#  'louiswferreira design minor tweak small detail matter',
#  'engineer feed haha',
#  'close actual expected flight http ruediphtil',
#  'nigel lockyer excited supercollider considerably larger http typirk',
#  'wholemarsblog steezyysosa austinteslaclub joetegtmeyer peterdog txterafactory terafactorytx lqdchkn http pqsjzopaj',
#  'steezyysosa austinteslaclub joetegtmeyer peterdog txterafactory terafactorytx lqdchkn jd average http ozazv igxa',
#  'austinteslaclub joetegtmeyer peterdog txterafactory terafactorytx lqdchkn jd average eliburton tesla tex http iniry e',
#  'kyzcralotsxam',
#  'penguin random house change random penguin',
#  'austinbarnard short livestream lot wrong provide video wa http jmojn hhxs',
#  'fnarolles tgmetsfan matter',
#  'erdayastronaut klotzadam nasaspaceflight tested scale version wind tunnel active aero clos http xzlzvsaq',
#  'flcnhvy rgvaerialphotos http hez otgjjh',
#  'rgvaerialphotos lord',
#  'tgmetsfan klotzadam nasaspaceflight erdayastronaut yeah fails end landing http daqdiiwb',
#  'flcnhvy nasaspaceflight erdayastronaut minor',
#  'klotzadam nasaspaceflight erdayastronaut understanding body flap control pitch yaw amp roll duri http jvi',
#  'nasaspaceflight erdayastronaut rud launch pad fortunately sn ready',
#  'nasaspaceflight erdayastronaut stable controlled descent body flap great transferring propellant http vpiippdv',
#  'teslaownerssv kristennetten teslatino day',
#  'kristennetten teslaownerssv teslatino fault point probability fault wi http inu xajd',
#  'teslaownerssv teslatino measure primarily intervention probability update addressed issu http zyf efd ih',
#  'teslatino great autopilot ai team working super hard neural net testing http mnn srre',
#  'auchenberg latency improve significantly bandwidth',
#  'teslaownerssv build noticeably intervention',
#  'rationaletienne teslaownerssv toadmeister',
#  'teslaownerssv toadmeister spent half life california amp love state frankly http xouoedjt',
#  'toadmeister sweden death oct http lygotobi',
#  'tocnewyorkstate true fewer heart attack easier pump blood gravity',
#  'malekkhelifi inety prince engineer feed talking stephenson constellation scrotum haha',
#  'engineer feed small fry sun convert million ton mass energy',
#  'wholemarsblog accurate',
#  'ajtourville endelsound grimezsz http hx tla',
#  'bluemoondance spacepadreisle challenge high wind sunday static fire',
#  'spacepadreisle great shot',
#  'endelsound grimezsz future ai',
#  'teslarati truth stranger fiction',
#  'waitbutwhy',
#  'universal sci urf smol',
#  'homantse long time',
#  'truth told eaten jitb time year teriyaki bowl',
#  'buy jack box footstool',
#  'skorusark approximately log rate',
#  'challengerst bot change setting combat',
#  'samtalkstesla phased array antenna flat',
#  'tesla make catgirl robot',
#  'machinepix crane toy',
#  'coffeemaestro',
#  '',
#  'wow mayo salty',
#  'ppathole pcgamer max payne great level silent hill good',
#  'jack box double duty sperm donor clinic',
#  'thewpmontgomery pcgamer game',
#  'thatdudeshannon pcgamer fear modern graphic amp sound rock',
#  'matthewgarcia pcgamer',
#  'zzcool pcgamer game thread scarier amp creatively horror movie',
#  'pcgamer fear imo dead space haunt dream',
#  'rakyll http agokwqpv',
#  'jgrano flcnhvy knowledge literally equipment usable major repair upgra http vrwvop qd',
#  'flcnhvy left broken bot amp equipment worth scrap metal scrounged spa http ywqqasrbt',
#  'flcnhvy employee factory gm toyota left good equipment amp http dfuastpm',
#  'ajtourville bettern nothin ur back',
#  'wholemarsblog ab',
#  'hyperchangetv tesla team great work',
#  'hyperchangetv tbh capex efficiency trash',
#  'westcoastbill testing covid license print money',
#  'arctechinc tesla helpful beta tester',
#  'erdayastronaut video training amp inference essential excellent autonomy',
#  'engineer feed sigh supersonic jet time electric',
#  'worldandscience critical humanity future',
#  'congratulation spacex team http',
#  'teslatino mine day ahead',
#  'eliburton teslaownerssv option setting',
#  'teslaownerssv visualization tone significantly production intentionally strident color',
#  'erdayastronaut tobyliiiiiiiiii austinbarnard superclusterhq',
#  'erdayastronaut tobyliiiiiiiiii austinbarnard superclusterhq boca week talk http vb wd bsc',
#  'tobyliiiiiiiiii austinbarnard superclusterhq good point week form written piece spacex website',
#  'austinbarnard superclusterhq great pic beginning starship production system meaningful',
#  'wholemarsblog yup beta update lot step fwd step back situation pace improv http xcsvngdo',
#  'bart sander working fart car command',
#  'spacepadreisle starship coming',
#  'price change pushed thursday week applies week clock start countr http cjhtxcselt',
#  'austinbarnard deg glass star bar tbd top high bay',
#  'dmc ryan time price rise product functionality improves ti http xmemo nu',
#  'stephenking agreed performance tire',
#  'spacex small issue loss upper stage camera standing http zk vr xwzl',
#  'flcnhvy',
#  'tesla fsd beta limited release fsd price upgrade monday',
#  'teslagong ppathole teslaownerssv tesla raj complete testing amp regulator approve differe http uoa jncx',
#  'ppathole teslaownerssv tesla raj',
#  'teslaownerssv tesla raj haha',
#  'teslarati dependent proving high safety',
#  'wholemarsblog intentional wanted show theoretically convert entire vehicle http pczpbd jj',
#  'erdayastronaut cold gas hot',
#  'rubix ya ta tiki bar',
#  'starship nosecone high bay amp tiki bar http qxyxmmiuj',
#  'ieeeorg',
#  'erdayastronaut orbit time',
#  'erdayastronaut melty tbh',
#  'erdayastronaut engine bar dicey pushing term test achieve http pulpf',
#  'erdayastronaut raptor run sec bar chamber pressure encountering issue mt sea http rg erwhznt',
#  'fsd beta rollout happening tonight extremely slow amp cautious',
#  'data engine starship static fire morning good proceeding nosecone mate',
#  'ppathole toadmeister population life month lost lockdown amp restriction http ct svangy',
#  'toadmeister sweden death oct http gy ummx',
#  'joshtownsend',
#  'juanjacobs jwangark firmware slightly accurate description',
#  'rt tesla place home solar roof kansa ranch installed day',
#  'ppathole flyerandyp mojosusan mobi mobility fusion mobi haha',
#  'flyerandyp mojosusan neck http vcoaxsrv',
#  'flyerandyp mojosusan helpful mobi disc put st surgery failed remov http czykfyo ix',
#  'jwangark pretty accurate dna sequencing synthetic dna rna fix bug code http gcysvghm',
#  'samtalkstesla london beijing cool',
#  'samtalkstesla wow trip',
#  'cinotpyrc kid haha',
#  'tr http yo jkbs',
#  'techamazing snoopy',
#  'tesmanian current production slightly',
#  'bamtheteslaman cleantechnica life solar system ice europa http izk gi',
#  'rt tesmanian tesla model sr lowest energy consumption bevs report http wt',
#  'cleantechnica creative',
#  'flcnhvy free fusion reactor sky conveniently convert million ton mass energy http owmreup',
#  'kristennetten teslaownerssv',
#  'ppathole',
#  'xbox',
#  'whatsupfranks kimpaquette system autodelete data automatically default',
#  'univercurious table tension',
#  'kimpaquette',
#  'teslaownerssv starting production seater month initial delivery early december',
#  'gauntlet thrown prophecy fulfilled model price tonight',
#  'neopork spacex nasaspaceflight austinbarnard whoisheartbreak erdayastronaut felixschlang http mrscc',
#  'gem mingen tesla congratulation',
#  'teslarati making progress',
#  'meter roughly ft diameter',
#  'roomy vacuum rocket engine added http pktdfdizyc',
#  'flcnhvy wholemarsblog kristennetten boringcompany tesla focus vega amp prufrock tunneling machine',
#  'astrojordy kristennetten boringcompany tesla',
#  'wholemarsblog kristennetten boringcompany tesla month finishing touch station',
#  'kristennetten boringcompany tesla simplified lot basically tesla tunnel point http xhs awxb',
#  'playoverwatch sweet',
#  'antonkanerva slow phased array antenna',
#  'lexfridman nice',
#  'love baby hurt winston churchill',
#  'playoverwatch twomad weak turret strategic degree freedom',
#  'playoverwatch twomad buff torb turret',
#  'twomad um',
#  'teslaownerssv goosebump merch tbh',
#  'teslaownerssv hg',
#  'teslaownerssv lotr',
#  'illuminaughty',
#  'chotihaque billgates dougstanhope bobdylan charltonbrooker ericidle jimcarrey johncleese sapinker knee deep',
#  'rt spacex flight upgraded cargo version dragon carry science payload',
#  'rt spacex dragon spacecraft supporting spacex st cargo resupply mission space station departed hawthorne factory',
#  'chipro yeah',
#  'wr nygov success set outcome time',
#  'bad life wholemarsblog dy move direction tough position wi http tdf',
#  'flcnhvy good grief spacex money starship designed carry people amp cargo ear http qm kycr',
#  'teslarati fsd stuck lot local maximum clear hit ceiling time',
#  'rationaletienne delayslater accurate haha',
#  'delayslater graph appears upside',
#  'teslarati sheer magnitude entire production system hard element productio http p oelk',
#  'teslaclubin cleantechnica release order configurator jan',
#  'cleantechnica limited fsd beta releasing tuesday week promised limited http qrymb ii',
#  ...]

# %%
txt=' '.join(X)
txt
# Out:
# 'kunalb alien id aa carmack ray tracing cyberpunk hdr level joerogan spotify great interview gtera doge underestimated teslacn congratulation tesla china amazing execution year happy year ox http wfkmyu oj frodo underdoge thought fail http zgxjfdzzrm owensparks flcnhvy anonyx haha flcnhvy anonyx tweet represent real world time allocation entertaining outcome givedirectly agree clubhouse kanyewest http rwe uhsts geoffkeighley unrealengine real bought dogecoin lil toddler hodler joshmanmode issue sentencing bit high freewalletorg fixing freewalletorg unlock account astrojordy true power haha http fc uhqsd freewalletorg crypto wallet give private key avoided cost freewalletorg app suck rt spacex nasa selected falcon heavy launch element lunar gateway mission http pwt ajtourville blkmdl rationaletienne adamklotz predict cash flow starlink ipo rationaletienne adamklotz starlink staggeringly difficult technical amp economic endeavor http ac skqx rationaletienne adamklotz spacex pas deep chasm negative cash flow year http hdjl id aa carmack lowest cost ton carbon sequestered net product made scalable http xmyi qwsgw adamklotz meant price country difference tax amp shipping tobyliiiiiiiiii intended earth idea apply mar cryptoshrikar coindesk tesla dan palmer xprize team manage carbon capture prize http fsw ianl sruhle tesla receives stock comp stock option table missing back work capybarasurfer mattwallace bit high itsallrisky doge appears inflationary meaningfully fixed coin unit time http uh rarc michaelgalanin kevinmgill wow erdayastronaut michaelhodapp orbital launch tower stack raptor orbit booster improve ship amp booster mass michaelhodapp back work tonight ogecoin instructional video http ueeocofctb people spoken http ovmztgo nivetha lexfridman cute univercurious extremely misleading image reflect true time cost people rain amp pain doge hodl rainforest finally http gf rg qoaf itsallrisky fun crypto joshroomsburg snoopdogg genesimmons simplicity genius astro dogg spacex yup jbuttermost dogecoinrich wapodavenport true dogecoinrich flcnhvy astrojordy easy decade intense work note email text astrojordy lesson learned earth mar time story tesla amp spacex theonion read thebabylonbee great kingdom http je ei hmv dumdin grimezsz heard year grimezsz dogecake yolt http cnof yjpf kristennetten damian kristennetten yeah owensparks great thing restaurant hang stranger sjm future currency earth redlineshifter scratch wow rationaletienne wonderofscience destiny renatakonkoly teslarati woodhaus franz essential erdayastronaut josh bickett ajtourville spacex ship landing burn clear solution greate http wikiugkz adamklotz erdayastronaut josh bickett ajtourville spacex hot gas maneuvering rcs thruster http vso ioed erdayastronaut josh bickett ajtourville spacex higher isp erdayastronaut josh bickett ajtourville spacex intuitively turbopump fed raptor mu http lbtg sibuc brendan nasaspaceflight rt spacex falcon launch nasa spherex mission collect data million galaxy explore rt spacex falcon launch starlink satellite orbit mission pad deck http cucbgpnx mikko darudevil true josh bickett ajtourville erdayastronaut spacex yeah default engine lever arm shut good ajtourville erdayastronaut spacex engine min throttle point flameout risk la http thniyssnwn adamklotz erdayastronaut spacex erdayastronaut spacex foolish start engine amp immediately shut needed land meme destroyer short commander cruz happen sandstorm masterpiece madoverlord dumb time pull method http whlrdr low key loki high low doge gigachad dogecoin people crypto ur http kf klxb huobiglobal entertaining outcome doge http vviuzwhodt erdayastronaut high sea amp wind tough http bey pefpcj rt spacex watch falcon launch starlink satellite http bjfjlczwdk http ln reesbw twitter filled graffiti art eiraum giga berlin progress http ekpg qcbui hamoon neuralink neuralink working super hard ensure implant safety amp close communication http yky llpumd rt spacex mission enables access everyday peopl ...

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Generate wordcloud
stop.append('will')
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', max_words=100,colormap='Set2',stopwords=stop).generate(txt)
# Plot
plot_cloud(wordcloud)

# %%
##Part Of Speech Tagging
nlp = spacy.load("en_core_web_sm")
doc_block = nlp(txt)
spacy.displacy.render(doc_block, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">kunalb alien id aa carmack ray tracing cyberpunk hdr level joerogan spotify great interview gtera doge underestimated teslacn congratulation tesla china amazing execution
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  happy year ox http wfkmyu oj frodo underdoge thought fail http zgxjfdzzrm owensparks flcnhvy anonyx haha flcnhvy anonyx tweet represent real world time allocation entertaining outcome givedirectly agree clubhouse kanyewest http rwe uhsts geoffkeighley unrealengine real bought dogecoin lil toddler hodler joshmanmode issue sentencing bit high freewalletorg fixing freewalletorg unlock account astrojordy true power haha http fc uhqsd freewalletorg crypto wallet give private key avoided cost freewalletorg app suck rt spacex nasa selected falcon heavy launch element lunar gateway mission http pwt ajtourville blkmdl rationaletienne adamklotz predict cash flow starlink ipo rationaletienne adamklotz starlink staggeringly difficult technical amp economic endeavor http ac skqx rationaletienne adamklotz spacex pas deep chasm negative cash flow year http hdjl id aa carmack lowest cost ton carbon sequestered net product made scalable http xmyi qwsgw adamklotz meant price country difference tax amp shipping tobyliiiiiiiiii intended earth idea apply mar cryptoshrikar coindesk tesla dan palmer xprize team manage carbon capture prize http fsw ianl sruhle tesla receives stock comp stock option table missing back work capybarasurfer mattwallace bit high itsallrisky doge appears inflationary meaningfully fixed coin unit time http uh rarc michaelgalanin kevinmgill wow erdayastronaut michaelhodapp orbital launch tower stack raptor orbit booster improve ship amp booster mass michaelhodapp back work
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tonight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  ogecoin instructional video http ueeocofctb people spoken http ovmztgo nivetha lexfridman cute univercurious extremely misleading image reflect true time cost people rain amp pain doge hodl rainforest finally http gf rg qoaf itsallrisky fun crypto joshroomsburg snoopdogg genesimmons simplicity genius astro dogg spacex yup jbuttermost dogecoinrich wapodavenport true dogecoinrich flcnhvy astrojordy easy decade intense work note email text astrojordy lesson learned earth mar time story tesla amp spacex theonion read thebabylonbee great kingdom http je ei hmv dumdin grimezsz heard year grimezsz dogecake yolt http cnof yjpf kristennetten damian kristennetten yeah owensparks great thing restaurant hang stranger sjm future currency earth redlineshifter scratch wow rationaletienne wonderofscience destiny renatakonkoly teslarati woodhaus franz essential erdayastronaut josh bickett ajtourville spacex ship landing burn clear solution greate http wikiugkz adamklotz erdayastronaut josh bickett ajtourville spacex hot gas maneuvering rcs thruster http vso ioed erdayastronaut josh bickett ajtourville spacex higher isp erdayastronaut josh bickett ajtourville spacex intuitively turbopump fed raptor mu http lbtg sibuc brendan nasaspaceflight rt spacex falcon launch nasa spherex mission collect data million galaxy explore rt spacex falcon launch starlink satellite orbit mission pad deck http cucbgpnx mikko darudevil true josh bickett ajtourville erdayastronaut spacex yeah default engine lever arm shut good ajtourville erdayastronaut spacex engine min throttle point flameout risk la http thniyssnwn adamklotz erdayastronaut spacex erdayastronaut spacex foolish start engine amp immediately shut needed land meme destroyer short commander cruz happen sandstorm masterpiece madoverlord dumb time pull method http whlrdr low key loki high low doge gigachad dogecoin people crypto ur http kf klxb huobiglobal entertaining outcome doge http vviuzwhodt erdayastronaut high sea amp wind tough http bey pefpcj rt spacex watch falcon launch starlink satellite http bjfjlczwdk http ln reesbw twitter filled graffiti art eiraum giga berlin progress http ekpg qcbui hamoon neuralink neuralink working super hard ensure implant safety amp close communication http yky llpumd rt spacex mission enables access everyday people dream space rt spacex announcing commercial astronaut mission orbit earth aboard dragon http mbesvnakad http uklsjffrjk worked advanced wearable phone robot skill needed neuralink feel weird helping make good version cyberpunk true working neuralink short term solve brain spine injury long term human ai symbiosis latte http qrc alads http xccokojylt clubhouse
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tonight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  pm la time erdayastronaut tj cooney lrocket spacex felixschlang marcushousegame tom great story experim http teezkiwcmk rt commercial crew launch alert nasa spacex targeting
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier april
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  launch crew rotation mi erdayastronaut tj cooney lrocket spacex felixschlang marcushousegame big fan methane http mdv vdefyc tj cooney lrocket spacex felixschlang marcushousegame sound correct tom deserves lot cre http hdri hfa tj cooney lrocket spacex felixschlang marcushousegame tom great amp instrumental developing early vers http ulxtclm ercxspace smvllstvrs accelerate unusually fast high important reusable http cprrqj dogg teslaownerssv escaping thebabylonbee read article warm sunny day amp snowy mountain http psyqu beautiful day la http escjtbzo jaylav yeah dr frankensteen http wdj ujqk younesh guy gave talk spacex flcnhvy halo http pyrcfe xp carnage life hope true tesla spacex thejackbeyer nasaspaceflight cryoproof install engine starship sn amp sn http urtpjn amo retrospect inevitable rgvaerialphotos great shot menieb live sword die sword lexfridman entropy teslaownerssv gamespot buy amp hold company make good amp produce service love engineer feed earth small amp smaller http gtohclgj gamespot cyberpunk hotfixes literally hotfixes great game http kmk pegm documentingbtc dollar shorting westcoastbill johnnacrider iupsychdoctor aoc robinhoodapp shopify great spacex ohqwix bnnj bcghvzqxlb wimgrommen wsbchairman economy making product amp providing great service matter iupsychdoctor aoc robinhoodapp tanstaafl small fee fee make robin http czrhlolyvo shorty apologist give respect shorty sell house sell car sell stock b sh http vjkf bqbod rationaletienne teslavangelist delayslater finishing engineering year production start
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  aiming release candidate desig http bfverxpoqu ppathole grimezsz made video aoc robinhoodapp absolutely nasaspaceflight unlike aircraft division fine faa space division fundamentally broken reg http si axbjbz evankaylor nomad anbuteau esthetic cyberpunk incredible btw interior design trevormahlmann spacex major est

# %%
all_scores = all_words.set_index(0)['Value'].to_dict()
all_scores
# Out:
# {'abnormal': -1,
#  'abolish': -1,
#  'abominable': -1,
#  'abominably': -1,
#  'abominate': -1,
#  'abomination': -1,
#  'abort': -1,
#  'aborted': -1,
#  'aborts': -1,
#  'abrade': -1,
#  'abrasive': -1,
#  'abrupt': -1,
#  'abruptly': -1,
#  'abscond': -1,
#  'absence': -1,
#  'absent-minded': -1,
#  'absentee': -1,
#  'absurd': -1,
#  'absurdity': -1,
#  'absurdly': -1,
#  'absurdness': -1,
#  'abuse': -1,
#  'abused': -1,
#  'abuses': -1,
#  'abusive': -1,
#  'abysmal': -1,
#  'abysmally': -1,
#  'abyss': -1,
#  'accidental': -1,
#  'accost': -1,
#  'accursed': -1,
#  'accusation': -1,
#  'accusations': -1,
#  'accuse': -1,
#  'accuses': -1,
#  'accusing': -1,
#  'accusingly': -1,
#  'acerbate': -1,
#  'acerbic': -1,
#  'acerbically': -1,
#  'ache': -1,
#  'ached': -1,
#  'aches': -1,
#  'achey': -1,
#  'aching': -1,
#  'acrid': -1,
#  'acridly': -1,
#  'acridness': -1,
#  'acrimonious': -1,
#  'acrimoniously': -1,
#  'acrimony': -1,
#  'adamant': -1,
#  'adamantly': -1,
#  'addict': -1,
#  'addicted': -1,
#  'addicting': -1,
#  'addicts': -1,
#  'admonish': -1,
#  'admonisher': -1,
#  'admonishingly': -1,
#  'admonishment': -1,
#  'admonition': -1,
#  'adulterate': -1,
#  'adulterated': -1,
#  'adulteration': -1,
#  'adulterier': -1,
#  'adversarial': -1,
#  'adversary': -1,
#  'adverse': -1,
#  'adversity': -1,
#  'afflict': -1,
#  'affliction': -1,
#  'afflictive': -1,
#  'affront': -1,
#  'afraid': -1,
#  'aggravate': -1,
#  'aggravating': -1,
#  'aggravation': -1,
#  'aggression': -1,
#  'aggressive': -1,
#  'aggressiveness': -1,
#  'aggressor': -1,
#  'aggrieve': -1,
#  'aggrieved': -1,
#  'aggrivation': -1,
#  'aghast': -1,
#  'agonies': -1,
#  'agonize': -1,
#  'agonizing': -1,
#  'agonizingly': -1,
#  'agony': -1,
#  'aground': -1,
#  'ail': -1,
#  'ailing': -1,
#  'ailment': -1,
#  'aimless': -1,
#  'alarm': -1,
#  'alarmed': -1,
#  'alarming': -1,
#  'alarmingly': -1,
#  'alienate': -1,
#  'alienated': -1,
#  'alienation': -1,
#  'allegation': -1,
#  'allegations': -1,
#  'allege': -1,
#  'allergic': -1,
#  'allergies': -1,
#  'allergy': -1,
#  'aloof': -1,
#  'altercation': -1,
#  'ambiguity': -1,
#  'ambiguous': -1,
#  'ambivalence': -1,
#  'ambivalent': -1,
#  'ambush': -1,
#  'amiss': -1,
#  'amputate': -1,
#  'anarchism': -1,
#  'anarchist': -1,
#  'anarchistic': -1,
#  'anarchy': -1,
#  'anemic': -1,
#  'anger': -1,
#  'angrily': -1,
#  'angriness': -1,
#  'angry': -1,
#  'anguish': -1,
#  'animosity': -1,
#  'annihilate': -1,
#  'annihilation': -1,
#  'annoy': -1,
#  'annoyance': -1,
#  'annoyances': -1,
#  'annoyed': -1,
#  'annoying': -1,
#  'annoyingly': -1,
#  'annoys': -1,
#  'anomalous': -1,
#  'anomaly': -1,
#  'antagonism': -1,
#  'antagonist': -1,
#  'antagonistic': -1,
#  'antagonize': -1,
#  'anti-': -1,
#  'anti-american': -1,
#  'anti-israeli': -1,
#  'anti-occupation': -1,
#  'anti-proliferation': -1,
#  'anti-semites': -1,
#  'anti-social': -1,
#  'anti-us': -1,
#  'anti-white': -1,
#  'antipathy': -1,
#  'antiquated': -1,
#  'antithetical': -1,
#  'anxieties': -1,
#  'anxiety': -1,
#  'anxious': -1,
#  'anxiously': -1,
#  'anxiousness': -1,
#  'apathetic': -1,
#  'apathetically': -1,
#  'apathy': -1,
#  'apocalypse': -1,
#  'apocalyptic': -1,
#  'apologist': -1,
#  'apologists': -1,
#  'appal': -1,
#  'appall': -1,
#  'appalled': -1,
#  'appalling': -1,
#  'appallingly': -1,
#  'apprehension': -1,
#  'apprehensions': -1,
#  'apprehensive': -1,
#  'apprehensively': -1,
#  'arbitrary': -1,
#  'arcane': -1,
#  'archaic': -1,
#  'arduous': -1,
#  'arduously': -1,
#  'argumentative': -1,
#  'arrogance': -1,
#  'arrogant': -1,
#  'arrogantly': -1,
#  'ashamed': -1,
#  'asinine': -1,
#  'asininely': -1,
#  'asinininity': -1,
#  'askance': -1,
#  'asperse': -1,
#  'aspersion': -1,
#  'aspersions': -1,
#  'assail': -1,
#  'assassin': -1,
#  'assassinate': -1,
#  'assault': -1,
#  'assult': -1,
#  'astray': -1,
#  'asunder': -1,
#  'atrocious': -1,
#  'atrocities': -1,
#  'atrocity': -1,
#  'atrophy': -1,
#  'attack': -1,
#  'attacks': -1,
#  'audacious': -1,
#  'audaciously': -1,
#  'audaciousness': -1,
#  'audacity': -1,
#  'audiciously': -1,
#  'austere': -1,
#  'authoritarian': -1,
#  'autocrat': -1,
#  'autocratic': -1,
#  'avalanche': -1,
#  'avarice': -1,
#  'avaricious': -1,
#  'avariciously': -1,
#  'avenge': -1,
#  'averse': -1,
#  'aversion': -1,
#  'aweful': -1,
#  'awful': -1,
#  'awfully': -1,
#  'awfulness': -1,
#  'awkward': -1,
#  'awkwardness': -1,
#  'ax': -1,
#  'babble': -1,
#  'back-logged': -1,
#  'back-wood': -1,
#  'back-woods': -1,
#  'backache': -1,
#  'backaches': -1,
#  'backaching': -1,
#  'backbite': -1,
#  'backbiting': -1,
#  'backward': -1,
#  'backwardness': -1,
#  'backwood': -1,
#  'backwoods': -1,
#  'bad': -1,
#  'badly': -1,
#  'baffle': -1,
#  'baffled': -1,
#  'bafflement': -1,
#  'baffling': -1,
#  'bait': -1,
#  'balk': -1,
#  'banal': -1,
#  'banalize': -1,
#  'bane': -1,
#  'banish': -1,
#  'banishment': -1,
#  'bankrupt': -1,
#  'barbarian': -1,
#  'barbaric': -1,
#  'barbarically': -1,
#  'barbarity': -1,
#  'barbarous': -1,
#  'barbarously': -1,
#  'barren': -1,
#  'baseless': -1,
#  'bash': -1,
#  'bashed': -1,
#  'bashful': -1,
#  'bashing': -1,
#  'bastard': -1,
#  'bastards': -1,
#  'battered': -1,
#  'battering': -1,
#  'batty': -1,
#  'bearish': -1,
#  'beastly': -1,
#  'bedlam': -1,
#  'bedlamite': -1,
#  'befoul': -1,
#  'beg': -1,
#  'beggar': -1,
#  'beggarly': -1,
#  'begging': -1,
#  'beguile': -1,
#  'belabor': -1,
#  'belated': -1,
#  'beleaguer': -1,
#  'belie': -1,
#  'belittle': -1,
#  'belittled': -1,
#  'belittling': -1,
#  'bellicose': -1,
#  'belligerence': -1,
#  'belligerent': -1,
#  'belligerently': -1,
#  'bemoan': -1,
#  'bemoaning': -1,
#  'bemused': -1,
#  'bent': -1,
#  'berate': -1,
#  'bereave': -1,
#  'bereavement': -1,
#  'bereft': -1,
#  'berserk': -1,
#  'beseech': -1,
#  'beset': -1,
#  'besiege': -1,
#  'besmirch': -1,
#  'bestial': -1,
#  'betray': -1,
#  'betrayal': -1,
#  'betrayals': -1,
#  'betrayer': -1,
#  'betraying': -1,
#  'betrays': -1,
#  'bewail': -1,
#  'beware': -1,
#  'bewilder': -1,
#  'bewildered': -1,
#  'bewildering': -1,
#  'bewilderingly': -1,
#  'bewilderment': -1,
#  'bewitch': -1,
#  'bias': -1,
#  'biased': -1,
#  'biases': -1,
#  'bicker': -1,
#  'bickering': -1,
#  'bid-rigging': -1,
#  'bigotries': -1,
#  'bigotry': -1,
#  'bitch': -1,
#  'bitchy': -1,
#  'biting': -1,
#  'bitingly': -1,
#  'bitter': -1,
#  'bitterly': -1,
#  'bitterness': -1,
#  'bizarre': -1,
#  'blab': -1,
#  'blabber': -1,
#  'blackmail': -1,
#  'blah': -1,
#  'blame': -1,
#  'blameworthy': -1,
#  'bland': -1,
#  'blandish': -1,
#  'blaspheme': -1,
#  'blasphemous': -1,
#  'blasphemy': -1,
#  'blasted': -1,
#  'blatant': -1,
#  'blatantly': -1,
#  'blather': -1,
#  'bleak': -1,
#  'bleakly': -1,
#  'bleakness': -1,
#  'bleed': -1,
#  'bleeding': -1,
#  'bleeds': -1,
#  'blemish': -1,
#  'blind': -1,
#  'blinding': -1,
#  'blindingly': -1,
#  'blindside': -1,
#  'blister': -1,
#  'blistering': -1,
#  'bloated': -1,
#  'blockage': -1,
#  'blockhead': -1,
#  'bloodshed': -1,
#  'bloodthirsty': -1,
#  'bloody': -1,
#  'blotchy': -1,
#  'blow': -1,
#  'blunder': -1,
#  'blundering': -1,
#  'blunders': -1,
#  'blunt': -1,
#  'blur': -1,
#  'bluring': -1,
#  'blurred': -1,
#  'blurring': -1,
#  'blurry': -1,
#  'blurs': -1,
#  'blurt': -1,
#  'boastful': -1,
#  'boggle': -1,
#  'bogus': -1,
#  'boil': -1,
#  'boiling': -1,
#  'boisterous': -1,
#  'bomb': -1,
#  'bombard': -1,
#  'bombardment': -1,
#  'bombastic': -1,
#  'bondage': -1,
#  'bonkers': -1,
#  'bore': -1,
#  'bored': -1,
#  'boredom': -1,
#  'bores': -1,
#  'boring': -1,
#  'botch': -1,
#  'bother': -1,
#  'bothered': -1,
#  'bothering': -1,
#  'bothers': -1,
#  'bothersome': -1,
#  'bowdlerize': -1,
#  'boycott': -1,
#  'braggart': -1,
#  'bragger': -1,
#  'brainless': -1,
#  'brainwash': -1,
#  'brash': -1,
#  'brashly': -1,
#  'brashness': -1,
#  'brat': -1,
#  'bravado': -1,
#  'brazen': -1,
#  'brazenly': -1,
#  'brazenness': -1,
#  'breach': -1,
#  'break': -1,
#  'break-up': -1,
#  'break-ups': -1,
#  'breakdown': -1,
#  'breaking': -1,
#  'breaks': -1,
#  'breakup': -1,
#  'breakups': -1,
#  'bribery': -1,
#  'brimstone': -1,
#  'bristle': -1,
#  'brittle': -1,
#  'broke': -1,
#  'broken': -1,
#  'broken-hearted': -1,
#  'brood': -1,
#  'browbeat': -1,
#  'bruise': -1,
#  'bruised': -1,
#  'bruises': -1,
#  'bruising': -1,
#  'brusque': -1,
#  'brutal': -1,
#  'brutalising': -1,
#  'brutalities': -1,
#  'brutality': -1,
#  'brutalize': -1,
#  'brutalizing': -1,
#  'brutally': -1,
#  'brute': -1,
#  'brutish': -1,
#  'bs': -1,
#  'buckle': -1,
#  'bug': -1,
#  'bugging': -1,
#  'buggy': -1,
#  'bugs': -1,
#  'bulkier': -1,
#  'bulkiness': -1,
#  'bulky': -1,
#  'bulkyness': -1,
#  'bull****': -1,
#  'bull----': -1,
#  'bullies': -1,
#  'bullshit': -1,
#  'bullshyt': -1,
#  'bully': -1,
#  'bullying': -1,
#  'bullyingly': -1,
#  'bum': -1,
#  'bump': -1,
#  'bumped': -1,
#  'bumping': -1,
#  'bumpping': -1,
#  'bumps': -1,
#  'bumpy': -1,
#  'bungle': -1,
#  'bungler': -1,
#  'bungling': -1,
#  'bunk': -1,
#  'burden': -1,
#  'burdensome': -1,
#  'burdensomely': -1,
#  'burn': -1,
#  'burned': -1,
#  'burning': -1,
#  'burns': -1,
#  'bust': -1,
#  'busts': -1,
#  'busybody': -1,
#  'butcher': -1,
#  'butchery': -1,
#  'buzzing': -1,
#  'byzantine': -1,
#  'cackle': -1,
#  'calamities': -1,
#  'calamitous': -1,
#  'calamitously': -1,
#  'calamity': -1,
#  'callous': -1,
#  'calumniate': -1,
#  'calumniation': -1,
#  'calumnies': -1,
#  'calumnious': -1,
#  'calumniously': -1,
#  'calumny': -1,
#  'cancer': -1,
#  'cancerous': -1,
#  'cannibal': -1,
#  'cannibalize': -1,
#  'capitulate': -1,
#  'capricious': -1,
#  'capriciously': -1,
#  'capriciousness': -1,
#  'capsize': -1,
#  'careless': -1,
#  'carelessness': -1,
#  'caricature': -1,
#  'carnage': -1,
#  'carp': -1,
#  'cartoonish': -1,
#  'cash-strapped': -1,
#  'castigate': -1,
#  'castrated': -1,
#  'casualty': -1,
#  'cataclysm': -1,
#  'cataclysmal': -1,
#  'cataclysmic': -1,
#  'cataclysmically': -1,
#  'catastrophe': -1,
#  'catastrophes': -1,
#  'catastrophic': -1,
#  'catastrophically': -1,
#  'catastrophies': -1,
#  'caustic': -1,
#  'caustically': -1,
#  'cautionary': -1,
#  'cave': -1,
#  'censure': -1,
#  'chafe': -1,
#  'chaff': -1,
#  'chagrin': -1,
#  'challenging': -1,
#  'chaos': -1,
#  'chaotic': -1,
#  'chasten': -1,
#  'chastise': -1,
#  'chastisement': -1,
#  'chatter': -1,
#  'chatterbox': -1,
#  'cheap': -1,
#  'cheapen': -1,
#  'cheaply': -1,
#  'cheat': -1,
#  'cheated': -1,
#  'cheater': -1,
#  'cheating': -1,
#  'cheats': -1,
#  'checkered': -1,
#  'cheerless': -1,
#  'cheesy': -1,
#  'chide': -1,
#  'childish': -1,
#  'chill': -1,
#  'chilly': -1,
#  'chintzy': -1,
#  'choke': -1,
#  'choleric': -1,
#  'choppy': -1,
#  'chore': -1,
#  'chronic': -1,
#  'chunky': -1,
#  'clamor': -1,
#  'clamorous': -1,
#  'clash': -1,
#  'cliche': -1,
#  'cliched': -1,
#  'clique': -1,
#  'clog': -1,
#  'clogged': -1,
#  'clogs': -1,
#  'cloud': -1,
#  'clouding': -1,
#  'cloudy': -1,
#  'clueless': -1,
#  'clumsy': -1,
#  'clunky': -1,
#  'coarse': -1,
#  'cocky': -1,
#  'coerce': -1,
#  'coercion': -1,
#  'coercive': -1,
#  'cold': -1,
#  'coldly': -1,
#  'collapse': -1,
#  'collude': -1,
#  'collusion': -1,
#  'combative': -1,
#  'combust': -1,
#  'comical': -1,
#  'commiserate': -1,
#  'commonplace': -1,
#  'commotion': -1,
#  'commotions': -1,
#  'complacent': -1,
#  'complain': -1,
#  'complained': -1,
#  'complaining': -1,
#  'complains': -1,
#  'complaint': -1,
#  'complaints': -1,
#  'complex': -1,
#  'complicated': -1,
#  'complication': -1,
#  'complicit': -1,
#  'compulsion': -1,
#  'compulsive': -1,
#  'concede': -1,
#  'conceded': -1,
#  'conceit': -1,
#  'conceited': -1,
#  'concen': -1,
#  'concens': -1,
#  'concern': -1,
#  'concerned': -1,
#  'concerns': -1,
#  'concession': -1,
#  'concessions': -1,
#  'condemn': -1,
#  'condemnable': -1,
#  'condemnation': -1,
#  'condemned': -1,
#  'condemns': -1,
#  'condescend': -1,
#  'condescending': -1,
#  'condescendingly': -1,
#  'condescension': -1,
#  'confess': -1,
#  'confession': -1,
#  'confessions': -1,
#  'confined': -1,
#  'conflict': -1,
#  'conflicted': -1,
#  'conflicting': -1,
#  'conflicts': -1,
#  'confound': -1,
#  'confounded': -1,
#  'confounding': -1,
#  'confront': -1,
#  'confrontation': -1,
#  'confrontational': -1,
#  'confuse': -1,
#  'confused': -1,
#  'confuses': -1,
#  'confusing': -1,
#  'confusion': -1,
#  'confusions': -1,
#  'congested': -1,
#  'congestion': -1,
#  'cons': -1,
#  'conscons': -1,
#  'conservative': -1,
#  'conspicuous': -1,
#  'conspicuously': -1,
#  'conspiracies': -1,
#  'conspiracy': -1,
#  'conspirator': -1,
#  'conspiratorial': -1,
#  'conspire': -1,
#  'consternation': -1,
#  'contagious': -1,
#  'contaminate': -1,
#  'contaminated': -1,
#  'contaminates': -1,
#  'contaminating': -1,
#  'contamination': -1,
#  'contempt': -1,
#  'contemptible': -1,
#  'contemptuous': -1,
#  'contemptuously': -1,
#  'contend': -1,
#  'contention': -1,
#  'contentious': -1,
#  'contort': -1,
#  'contortions': -1,
#  'contradict': -1,
#  'contradiction': -1,
#  'contradictory': -1,
#  'contrariness': -1,
#  'contravene': -1,
#  'contrive': -1,
#  'contrived': -1,
#  'controversial': -1,
#  'controversy': -1,
#  'convoluted': -1,
#  'corrode': -1,
#  'corrosion': -1,
#  'corrosions': -1,
#  'corrosive': -1,
#  'corrupt': -1,
#  'corrupted': -1,
#  'corrupting': -1,
#  'corruption': -1,
#  'corrupts': -1,
#  'corruptted': -1,
#  'costlier': -1,
#  'costly': -1,
#  'counter-productive': -1,
#  'counterproductive': -1,
#  'coupists': -1,
#  'covetous': -1,
#  'coward': -1,
#  'cowardly': -1,
#  'crabby': -1,
#  'crack': -1,
#  'cracked': -1,
#  'cracks': -1,
#  'craftily': -1,
#  'craftly': -1,
#  'crafty': -1,
#  'cramp': -1,
#  'cramped': -1,
#  'cramping': -1,
#  'cranky': -1,
#  'crap': -1,
#  'crappy': -1,
#  'craps': -1,
#  'crash': -1,
#  'crashed': -1,
#  'crashes': -1,
#  'crashing': -1,
#  'crass': -1,
#  'craven': -1,
#  'cravenly': -1,
#  'craze': -1,
#  'crazily': -1,
#  'craziness': -1,
#  'crazy': -1,
#  'creak': -1,
#  'creaking': -1,
#  'creaks': -1,
#  'credulous': -1,
#  'creep': -1,
#  'creeping': -1,
#  'creeps': -1,
#  'creepy': -1,
#  'crept': -1,
#  'crime': -1,
#  'criminal': -1,
#  'cringe': -1,
#  'cringed': -1,
#  'cringes': -1,
#  'cripple': -1,
#  'crippled': -1,
#  'cripples': -1,
#  'crippling': -1,
#  'crisis': -1,
#  'critic': -1,
#  'critical': -1,
#  'criticism': -1,
#  'criticisms': -1,
#  'criticize': -1,
#  'criticized': -1,
#  'criticizing': -1,
#  'critics': -1,
#  'cronyism': -1,
#  'crook': -1,
#  'crooked': -1,
#  'crooks': -1,
#  'crowded': -1,
#  'crowdedness': -1,
#  'crude': -1,
#  'cruel': -1,
#  'crueler': -1,
#  'cruelest': -1,
#  'cruelly': -1,
#  'cruelness': -1,
#  'cruelties': -1,
#  'cruelty': -1,
#  'crumble': -1,
#  'crumbling': -1,
#  'crummy': -1,
#  'crumple': -1,
#  'crumpled': -1,
#  'crumples': -1,
#  'crush': -1,
#  'crushed': -1,
#  'crushing': -1,
#  'cry': -1,
#  'culpable': -1,
#  'culprit': -1,
#  'cumbersome': -1,
#  'cunt': -1,
#  'cunts': -1,
#  'cuplrit': -1,
#  'curse': -1,
#  'cursed': -1,
#  'curses': -1,
#  'curt': -1,
#  'cuss': -1,
#  'cussed': -1,
#  'cutthroat': -1,
#  'cynical': -1,
#  'cynicism': -1,
#  'd*mn': -1,
#  'damage': -1,
#  'damaged': -1,
#  'damages': -1,
#  'damaging': -1,
#  'damn': -1,
#  'damnable': -1,
#  'damnably': -1,
#  'damnation': -1,
#  'damned': -1,
#  'damning': -1,
#  'damper': -1,
#  'danger': -1,
#  'dangerous': -1,
#  'dangerousness': -1,
#  'dark': -1,
#  'darken': -1,
#  'darkened': -1,
#  'darker': -1,
#  'darkness': -1,
#  'dastard': -1,
#  'dastardly': -1,
#  'daunt': -1,
#  'daunting': -1,
#  'dauntingly': -1,
#  'dawdle': -1,
#  'daze': -1,
#  'dazed': -1,
#  'dead': -1,
#  'deadbeat': -1,
#  'deadlock': -1,
#  'deadly': -1,
#  'deadweight': -1,
#  'deaf': -1,
#  'dearth': -1,
#  'death': -1,
#  'debacle': -1,
#  'debase': -1,
#  'debasement': -1,
#  'debaser': -1,
#  'debatable': -1,
#  'debauch': -1,
#  'debaucher': -1,
#  'debauchery': -1,
#  'debilitate': -1,
#  'debilitating': -1,
#  'debility': -1,
#  'debt': -1,
#  'debts': -1,
#  'decadence': -1,
#  'decadent': -1,
#  'decay': -1,
#  'decayed': -1,
#  'deceit': -1,
#  'deceitful': -1,
#  'deceitfully': -1,
#  'deceitfulness': -1,
#  'deceive': -1,
#  'deceiver': -1,
#  'deceivers': -1,
#  'deceiving': -1,
#  'deception': -1,
#  'deceptive': -1,
#  'deceptively': -1,
#  'declaim': -1,
#  'decline': -1,
#  'declines': -1,
#  'declining': -1,
#  'decrement': -1,
#  'decrepit': -1,
#  'decrepitude': -1,
#  'decry': -1,
#  'defamation': -1,
#  'defamations': -1,
#  'defamatory': -1,
#  'defame': -1,
#  'defect': -1,
#  'defective': -1,
#  'defects': -1,
#  'defensive': -1,
#  'defiance': -1,
#  'defiant': -1,
#  'defiantly': -1,
#  'deficiencies': -1,
#  'deficiency': -1,
#  'deficient': -1,
#  'defile': -1,
#  'defiler': -1,
#  'deform': -1,
#  'deformed': -1,
#  'defrauding': -1,
#  'defunct': -1,
#  'defy': -1,
#  'degenerate': -1,
#  'degenerately': -1,
#  'degeneration': -1,
#  'degradation': -1,
#  'degrade': -1,
#  'degrading': -1,
#  'degradingly': -1,
#  'dehumanization': -1,
#  'dehumanize': -1,
#  'deign': -1,
#  'deject': -1,
#  'dejected': -1,
#  'dejectedly': -1,
#  'dejection': -1,
#  'delay': -1,
#  'delayed': -1,
#  'delaying': -1,
#  'delays': -1,
#  'delinquency': -1,
#  'delinquent': -1,
#  'delirious': -1,
#  'delirium': -1,
#  'delude': -1,
#  'deluded': -1,
#  'deluge': -1,
#  'delusion': -1,
#  'delusional': -1,
#  'delusions': -1,
#  'demean': -1,
#  'demeaning': -1,
#  'demise': -1,
#  'demolish': -1,
#  'demolisher': -1,
#  'demon': -1,
#  'demonic': -1,
#  'demonize': -1,
#  'demonized': -1,
#  'demonizes': -1,
#  'demonizing': -1,
#  'demoralize': -1,
#  'demoralizing': -1,
#  'demoralizingly': -1,
#  'denial': -1,
#  'denied': -1,
#  'denies': -1,
#  'denigrate': -1,
#  'denounce': -1,
#  'dense': -1,
#  'dent': -1,
#  'dented': -1,
#  'dents': -1,
#  'denunciate': -1,
#  'denunciation': -1,
#  'denunciations': -1,
#  'deny': -1,
#  'denying': -1,
#  'deplete': -1,
#  'deplorable': -1,
#  'deplorably': -1,
#  'deplore': -1,
#  'deploring': -1,
#  'deploringly': -1,
#  'deprave': -1,
#  'depraved': -1,
#  'depravedly': -1,
#  'deprecate': -1,
#  'depress': -1,
#  'depressed': -1,
#  'depressing': -1,
#  'depressingly': -1,
#  'depression': -1,
#  'depressions': -1,
#  'deprive': -1,
#  'deprived': -1,
#  'deride': -1,
#  'derision': -1,
#  'derisive': -1,
#  'derisively': -1,
#  'derisiveness': -1,
#  'derogatory': -1,
#  'desecrate': -1,
#  'desert': -1,
#  'desertion': -1,
#  'desiccate': -1,
#  'desiccated': -1,
#  'desititute': -1,
#  'desolate': -1,
#  'desolately': -1,
#  'desolation': -1,
#  'despair': -1,
#  'despairing': -1,
#  'despairingly': -1,
#  'desperate': -1,
#  'desperately': -1,
#  'desperation': -1,
#  'despicable': -1,
#  'despicably': -1,
#  'despise': -1,
#  'despised': -1,
#  ...}

# %%
#Custom function :score each word in a sentence in lemmatised form, 
#but calculate the score for the whole original sentence.
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = all_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %%
# test that it works
calculate_sentiment(text = 'amazing')
# Out:
# 1

# %%
df['sentiment_value'] = df['Text'].apply(calculate_sentiment)

# %%
# how many words are in the sentence?
df['word_count'] = df['Text'].str.split().apply(len)
df['word_count'].head(20)
# Out:
# 0      4
# 1     13
# 2      4
# 3      4
# 4     17
# 5      7
# 6     14
# 7      6
# 8     11
# 9      8
# 10     4
# 11     7
# 12     1
# 13     5
# 14    13
# 15    12
# 16     4
# 17     5
# 18     2
# 19     6
# Name: word_count, dtype: int64

# %%
df.sort_values(by='sentiment_value').tail(10)
# Out:
#                                                    Text  sentiment_value  \
# 337   @PPathole Dojo isn’t needed, but will make sel...                3
# 992   @bad_at_life @WholeMarsBlog Diess is doing his...                3
# 1917  @wintonARK We better hustle with Neuralink. No...                3
# 468   @picot_john @CyberpunkGame It’s a good to grea...                4
# 1357  Great trip to Germany. Support from government...                4
# 1388  @GerberKawasaki Wow, I super loved astronomy (...                4
# 1510  @Teslarati We really need a bigger one, so adu...                4
# 770   Such a privilege to work with people I like &a...                4
# 1172  Thanks Tesla Team for great work on deliveries...                5
# 1304  One way or another, excitement guaranteed! Sup...                5
#
#       word_count
# 337           20
# 992           21
# 1917          10
# 468           20
# 1357          12
# 1388          20
# 1510          24
# 770           16
# 1172          20
# 1304          17

# %%
# Sentiment score of the whole review
df['sentiment_value'].describe()
# Out:
# count    1999.000000
# mean        0.216108
# std         0.856186
# min        -4.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         5.000000
# Name: sentiment_value, dtype: float64

# %%
# Sentiment score of the whole review
df[df['sentiment_value']<=0].head()
# Out:
#                                                 Text  sentiment_value  \
# 0                             @kunalb11 I’m an alien                0
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...                0
# 3                    @gtera27 Doge is underestimated               -1
# 6  Frodo was the underdoge,\nAll thought he would...               -1
# 8  @flcnhvy @anonyx10 Indeed! Tweets definitely d...                0
#
#    word_count
# 0           4
# 1          13
# 3           4
# 6          14
# 8          11

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(df['sentiment_value'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sentiment_value', ylabel='Density'>

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(y='sentiment_value',x=df.index,data=df)
# Out:
# <AxesSubplot:ylabel='sentiment_value'>

# %%
df.plot.scatter(x='word_count', y='sentiment_value', figsize=(8,8), title='Sentence sentiment value to sentence word count')
# Out:
# <AxesSubplot:title={'center':'Sentence sentiment value to sentence word count'}, xlabel='word_count', ylabel='sentiment_value'>

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
cv.fit_transform(X)
# Out:
# <1999x4941 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13536 stored elements in Compressed Sparse Row format>

# %%
len(cv.get_feature_names())
# Out:
# 4941

# %%
cv.vocabulary_
# Out:
# {'kunalb': 2287,
#  'alien': 131,
#  'id': 1949,
#  'aa': 0,
#  'carmack': 585,
#  'ray': 3397,
#  'tracing': 4337,
#  'cyberpunk': 916,
#  'hdr': 1804,
#  'level': 2364,
#  'joerogan': 2174,
#  'spotify': 3932,
#  'great': 1722,
#  'interview': 2075,
#  'gtera': 1741,
#  'doge': 1091,
#  'underestimated': 4452,
#  'teslacn': 4181,
#  'congratulation': 798,
#  'tesla': 4177,
#  'china': 670,
#  'amazing': 148,
#  'execution': 1341,
#  'year': 4851,
#  'happy': 1780,
#  'ox': 2993,
#  'http': 1909,
#  'wfkmyu': 4683,
#  'oj': 2909,
#  'frodo': 1567,
#  'underdoge': 4451,
#  'thought': 4257,
#  'fail': 1385,
#  'zgxjfdzzrm': 4907,
#  'owensparks': 2989,
#  'flcnhvy': 1494,
#  'anonyx': 178,
#  'haha': 1762,
#  'tweet': 4394,
#  'represent': 3488,
#  'real': 3417,
#  'world': 4753,
#  'time': 4273,
#  'allocation': 134,
#  'entertaining': 1268,
#  'outcome': 2968,
#  'givedirectly': 1680,
#  'agree': 95,
#  'clubhouse': 719,
#  'kanyewest': 2222,
#  'rwe': 3618,
#  'uhsts': 4422,
#  'geoffkeighley': 1655,
#  'unrealengine': 4480,
#  'bought': 476,
#  'dogecoin': 1093,
#  'lil': 2386,
#  'toddler': 4300,
#  'hodler': 1872,
#  'joshmanmode': 2186,
#  'issue': 2103,
#  'sentencing': 3714,
#  'bit': 419,
#  'high': 1848,
#  'freewalletorg': 1557,
#  'fixing': 1480,
#  'unlock': 4478,
#  'account': 31,
#  'astrojordy': 250,
#  'true': 4366,
#  'power': 3186,
#  'fc': 1420,
#  'uhqsd': 4421,
#  'crypto': 890,
#  'wallet': 4636,
#  'give': 1679,
#  'private': 3239,
#  'key': 2241,
#  'avoided': 306,
#  'cost': 845,
#  'app': 192,
#  'suck': 4049,
#  'rt': 3601,
#  'spacex': 3895,
#  'nasa': 2753,
#  'selected': 3706,
#  'falcon': 1393,
#  'heavy': 1818,
#  'launch': 2327,
#  'element': 1223,
#  'lunar': 2480,
#  'gateway': 1630,
#  'mission': 2654,
#  'pwt': 3312,
#  'ajtourville': 110,
#  'blkmdl': 435,
#  'rationaletienne': 3393,
#  'adamklotz': 55,
#  'predict': 3210,
#  'cash': 594,
#  'flow': 1502,
#  'starlink': 3966,
#  'ipo': 2091,
#  'staggeringly': 3956,
#  'difficult': 1041,
#  'technical': 4153,
#  'amp': 155,
#  'economic': 1188,
#  'endeavor': 1253,
#  'ac': 14,
#  'skqx': 3815,
#  'pas': 3037,
#  'deep': 975,
#  'chasm': 660,
#  'negative': 2777,
#  'hdjl': 1803,
#  'lowest': 2457,
#  'ton': 4310,
#  'carbon': 579,
#  'sequestered': 3721,
#  'net': 2782,
#  'product': 3253,
#  'made': 2494,
#  'scalable': 3663,
#  'xmyi': 4809,
#  'qwsgw': 3358,
#  'meant': 2578,
#  'price': 3226,
#  'country': 854,
#  'difference': 1039,
#  'tax': 4139,
#  'shipping': 3754,
#  'tobyliiiiiiiiii': 4297,
#  'intended': 2057,
#  'earth': 1172,
#  'idea': 1950,
#  'apply': 198,
#  'mar': 2524,
#  'cryptoshrikar': 891,
#  'coindesk': 737,
#  'dan': 934,
#  'palmer': 3014,
#  'xprize': 4817,
#  'team': 4148,
#  'manage': 2513,
#  'capture': 574,
#  'prize': 3241,
#  'fsw': 1574,
#  'ianl': 1943,
#  'sruhle': 3946,
#  'receives': 3429,
#  'stock': 4004,
#  'comp': 765,
#  'option': 2947,
#  'table': 4116,
#  'missing': 2653,
#  'back': 324,
#  'work': 4749,
#  'capybarasurfer': 576,
#  'mattwallace': 2554,
#  'itsallrisky': 2106,
#  'appears': 195,
#  'inflationary': 2024,
#  'meaningfully': 2577,
#  'fixed': 1479,
#  'coin': 736,
#  'unit': 4470,
#  'uh': 4420,
#  'rarc': 3387,
#  'michaelgalanin': 2621,
#  'kevinmgill': 2239,
#  'wow': 4759,
#  'erdayastronaut': 1280,
#  'michaelhodapp': 2622,
#  'orbital': 2951,
#  'tower': 4330,
#  'stack': 3953,
#  'raptor': 3385,
#  'orbit': 2950,
#  'booster': 468,
#  'improve': 1992,
#  'ship': 3752,
#  'mass': 2538,
#  'tonight': 4312,
#  'ogecoin': 2899,
#  'instructional': 2048,
#  'video': 4568,
#  'ueeocofctb': 4416,
#  'people': 3071,
#  'spoken': 3930,
#  'ovmztgo': 2986,
#  'nivetha': 2811,
#  'lexfridman': 2370,
#  'cute': 910,
#  'univercurious': 4471,
#  'extremely': 1366,
#  'misleading': 2651,
#  'image': 1979,
#  'reflect': 3448,
#  'rain': 3370,
#  'pain': 3011,
#  'hodl': 1871,
#  'rainforest': 3371,
#  'finally': 1461,
#  'gf': 1660,
#  'rg': 3528,
#  'qoaf': 3332,
#  'fun': 1582,
#  'joshroomsburg': 2187,
#  'snoopdogg': 3848,
#  'genesimmons': 1650,
#  'simplicity': 3791,
#  'genius': 1652,
#  'astro': 247,
#  'dogg': 1095,
#  'yup': 4884,
#  'jbuttermost': 2141,
#  'dogecoinrich': 1094,
#  'wapodavenport': 4640,
#  'easy': 1178,
#  'decade': 966,
#  'intense': 2058,
#  'note': 2836,
#  'email': 1233,
#  'text': 4216,
#  'lesson': 2361,
#  'learned': 2346,
#  'story': 4014,
#  'theonion': 4235,
#  'read': 3413,
#  'thebabylonbee': 4225,
#  'kingdom': 2255,
#  'je': 2146,
#  'ei': 1206,
#  'hmv': 1867,
#  'dumdin': 1148,
#  'grimezsz': 1733,
#  'heard': 1812,
#  'dogecake': 1092,
#  'yolt': 4868,
#  'cnof': 725,
#  'yjpf': 4862,
#  'kristennetten': 2282,
#  'damian': 931,
#  'yeah': 4850,
#  'thing': 4248,
#  'restaurant': 3501,
#  'hang': 1772,
#  'stranger': 4018,
#  'sjm': 3806,
#  'future': 1591,
#  'currency': 905,
#  'redlineshifter': 3439,
#  'scratch': 3678,
#  'wonderofscience': 4743,
#  'destiny': 1011,
#  'renatakonkoly': 3478,
#  'teslarati': 4196,
#  'woodhaus': 4744,
#  'franz': 1554,
#  'essential': 1296,
#  'josh': 2185,
#  'bickett': 402,
#  'landing': 2309,
#  'burn': 531,
#  'clear': 709,
#  'solution': 3863,
#  'greate': 1723,
#  'wikiugkz': 4707,
#  'hot': 1893,
#  'gas': 1626,
#  'maneuvering': 2515,
#  'rcs': 3405,
#  'thruster': 4263,
#  'vso': 4612,
#  'ioed': 2087,
#  'higher': 1849,
#  'isp': 2101,
#  'intuitively': 2077,
#  'turbopump': 4384,
#  'fed': 1428,
#  'mu': 2727,
#  'lbtg': 2337,
#  'sibuc': 3774,
#  'brendan': 498,
#  'nasaspaceflight': 2759,
#  'spherex': 3921,
#  'collect': 740,
#  'data': 946,
#  'million': 2638,
#  'galaxy': 1612,
#  'explore': 1357,
#  'satellite': 3653,
#  'pad': 3006,
#  'deck': 971,
#  'cucbgpnx': 897,
#  'mikko': 2632,
#  'darudevil': 945,
#  'default': 978,
#  'engine': 1259,
#  'lever': 2365,
#  'arm': 224,
#  'shut': 3770,
#  'good': 1701,
#  'min': 2643,
#  'throttle': 4260,
#  'point': 3156,
#  'flameout': 1490,
#  'risk': 3546,
#  'la': 2300,
#  'thniyssnwn': 4254,
#  'foolish': 1520,
#  'start': 3970,
#  'immediately': 1982,
#  'needed': 2775,
#  'land': 2307,
#  'meme': 2595,
#  'destroyer': 1012,
#  'short': 3757,
#  'commander': 755,
#  'cruz': 887,
#  'happen': 1776,
#  'sandstorm': 3644,
#  'masterpiece': 2540,
#  'madoverlord': 2496,
#  'dumb': 1146,
#  'pull': 3299,
#  'method': 2611,
#  'whlrdr': 4692,
#  'low': 2454,
#  'loki': 2432,
#  'gigachad': 1671,
#  'ur': 4502,
#  'kf': 2242,
#  'klxb': 2265,
#  'huobiglobal': 1921,
#  'vviuzwhodt': 4618,
#  'sea': 3688,
#  'wind': 4716,
#  'tough': 4328,
#  'bey': 396,
#  'pefpcj': 3065,
#  'watch': 4647,
#  'bjfjlczwdk': 426,
#  'ln': 2416,
#  'reesbw': 3444,
#  'twitter': 4401,
#  'filled': 1455,
#  'graffiti': 1713,
#  'art': 232,
#  'eiraum': 1210,
#  'giga': 1670,
#  'berlin': 385,
#  'progress': 3264,
#  'ekpg': 1215,
#  'qcbui': 3318,
#  'hamoon': 1769,
#  'neuralink': 2785,
#  'working': 4752,
#  'super': 4061,
#  'hard': 1781,
#  'ensure': 1265,
#  'implant': 1985,
#  'safety': 3633,
#  'close': 714,
#  'communication': 762,
#  'yky': 4863,
#  'llpumd': 2412,
#  'enables': 1248,
#  'access': 26,
#  'everyday': 1324,
#  'dream': 1119,
#  'space': 3884,
#  'announcing': 175,
#  'commercial': 759,
#  'astronaut': 253,
#  'aboard': 5,
#  'dragon': 1115,
#  'mbesvnakad': 2566,
#  'uklsjffrjk': 4428,
#  'worked': 4750,
#  'advanced': 71,
#  'wearable': 4664,
#  'phone': 3101,
#  'robot': 3569,
#  'skill': 3809,
#  'feel': 1432,
#  'weird': 4674,
#  'helping': 1830,
#  'make': 2507,
#  'version': 4555,
#  'term': 4172,
#  'solve': 3865,
#  'brain': 489,
#  'spine': 3924,
#  'injury': 2031,
#  'long': 2434,
#  'human': 1914,
#  'ai': 101,
#  'symbiosis': 4103,
#  'latte': 2326,
#  'qrc': 3338,
#  'alads': 116,
#  'xccokojylt': 4790,
#  'pm': 3146,
#  'tj': 4283,
#  'cooney': 836,
#  'lrocket': 2468,
#  'felixschlang': 1435,
#  'marcushousegame': 2526,
#  'tom': 4304,
#  'experim': 1351,
#  'teezkiwcmk': 4160,
#  'crew': 877,
#  'alert': 119,
#  'targeting': 4134,
#  'earlier': 1167,
#  'april': 208,
#  'rotation': 3587,
#  'mi': 2619,
#  'big': 404,
#  'fan': 1399,
#  'methane': 2610,
#  'mdv': 2573,
#  'vdefyc': 4543,
#  'sound': 3879,
#  'correct': 842,
#  'deserves': 1007,
#  'lot': 2447,
#  'cre': 871,
#  'hdri': 1805,
#  'hfa': 1842,
#  'instrumental': 2049,
#  'developing': 1021,
#  'early': 1168,
#  'vers': 4554,
#  'ulxtclm': 4438,
#  'ercxspace': 1278,
#  'smvllstvrs': 3839,
#  'accelerate': 18,
#  'unusually': 4484,
#  'fast': 1406,
#  'important': 1988,
#  'reusable': 3515,
#  'cprrqj': 863,
#  'teslaownerssv': 4192,
#  'escaping': 1293,
#  'article': 233,
#  'warm': 4642,
#  'sunny': 4060,
#  'day': 952,
#  'snowy': 3852,
#  'mountain': 2707,
#  'psyqu': 3293,
#  'beautiful': 366,
#  'escjtbzo': 1294,
#  'jaylav': 2137,
#  'dr': 1111,
#  'frankensteen': 1550,
#  'wdj': 4659,
#  'ujqk': 4425,
#  'younesh': 4870,
#  'guy': 1753,
#  'gave': 1634,
#  'talk': 4123,
#  'halo': 1766,
#  'pyrcfe': 3315,
#  'xp': 4814,
#  'carnage': 586,
#  'life': 2380,
#  'hope': 1887,
#  'thejackbeyer': 4230,
#  'cryoproof': 889,
#  'install': 2043,
#  'starship': 3968,
#  'sn': 3840,
#  'urtpjn': 4506,
#  'amo': 152,
#  'retrospect': 3510,
#  'inevitable': 2021,
#  'rgvaerialphotos': 3530,
#  'shot': 3764,
#  'menieb': 2598,
#  'live': 2404,
#  'sword': 4099,
#  'die': 1036,
#  'entropy': 1271,
#  'gamespot': 1614,
#  'buy': 538,
#  'hold': 1874,
#  'company': 766,
#  'produce': 3250,
#  'service': 3728,
#  'love': 2451,
#  'engineer': 1260,
#  'feed': 1430,
#  'small': 3830,
#  'smaller': 3831,
#  'gtohclgj': 1742,
#  'hotfixes': 1895,
#  'literally': 2401,
#  'game': 1613,
#  'kmk': 2270,
#  'pegm': 3066,
#  'documentingbtc': 1088,
#  'dollar': 1097,
#  'shorting': 3760,
#  'westcoastbill': 4680,
#  'johnnacrider': 2181,
#  'iupsychdoctor': 2111,
#  'aoc': 188,
#  'robinhoodapp': 3567,
#  'shopify': 3756,
#  'ohqwix': 2903,
#  'bnnj': 445,
#  'bcghvzqxlb': 360,
#  'wimgrommen': 4714,
#  'wsbchairman': 4771,
#  'economy': 1189,
#  'making': 2509,
#  'providing': 3288,
#  'matter': 2549,
#  'tanstaafl': 4131,
#  'fee': 1429,
#  'robin': 3566,
#  'czrhlolyvo': 924,
#  'shorty': 3763,
#  'apologist': 190,
#  'respect': 3497,
#  'sell': 3707,
#  'house': 1897,
#  'car': 577,
#  'sh': 3737,
#  'vjkf': 4591,
#  'bqbod': 485,
#  'teslavangelist': 4207,
#  'delayslater': 981,
#  'finishing': 1470,
#  'engineering': 1261,
#  'production': 3255,
#  'aiming': 104,
#  'release': 3461,
#  'candidate': 566,
#  'desig': 1008,
#  'bfverxpoqu': 398,
#  'ppathole': 3193,
#  'absolutely': 9,
#  'unlike': 4477,
#  'aircraft': 107,
#  'division': 1068,
#  'fine': 1467,
#  'faa': 1372,
#  'fundamentally': 1587,
#  'broken': 510,
#  'reg': 3452,
#  'si': 3772,
#  'axbjbz': 319,
#  'evankaylor': 1320,
#  'nomad': 2824,
#  'anbuteau': 163,
#  'esthetic': 1300,
#  'incredible': 2008,
#  'btw': 517,
#  'interior': 2066,
#  'design': 1009,
#  'trevormahlmann': 4356,
#  'major': 2505,
#  'improvement': 1994,
#  'coming': 752,
#  'dmc': 1079,
#  'ryan': 3622,
#  'roadster': 3563,
#  'part': 3030,
#  'rocket': 3573,
#  'lafebra': 2305,
#  'gfilche': 1661,
#  'storage': 4012,
#  'easily': 1177,
#  'upgradable': 4492,
#  'avalonpenrose': 301,
#  'djdzxq': 1071,
#  'maz': 2565,
#  'couch': 847,
#  'investor': 2083,
#  'teslanews': 4189,
#  'wholemarsblog': 4695,
#  'month': 2692,
#  'drive': 1124,
#  'prnd': 3242,
#  'stalk': 3959,
#  'stick': 3999,
#  'annoying': 176,
#  'shifter': 3750,
#  'guess': 1746,
#  'direction': 1050,
#  'based': 345,
#  'obstacle': 2871,
#  'see': 3702,
#  'context': 817,
#  'nav': 2765,
#  'map': 2522,
#  'ehq': 1205,
#  'qy': 3361,
#  'hedge': 1819,
#  'fund': 1585,
#  'shrubbery': 3768,
#  'wwqstaxm': 4779,
#  'rear': 3425,
#  'screen': 3679,
#  'mph': 2713,
#  'trap': 4351,
#  'speed': 3913,
#  'mile': 2634,
#  'top': 4317,
#  'tire': 4280,
#  'achieve': 36,
#  'second': 3698,
#  'play': 3139,
#  'plaid': 3132,
#  'model': 2677,
#  'hfuptnqipb': 1843,
#  'discord': 1055,
#  'corpo': 839,
#  'jason': 2133,
#  'wild': 4709,
#  'fxqkbce': 1602,
#  'andycolt': 167,
#  'waiting': 4634,
#  'review': 3519,
#  'gamestonk': 1615,
#  'rztkdzaewj': 3628,
#  'labpadre': 2304,
#  'passed': 3039,
#  'initial': 2029,
#  'pressure': 3222,
#  'test': 4210,
#  'adamhoov': 53,
#  'cffwac': 631,
#  'hand': 1771,
#  'knit': 2274,
#  'wool': 4746,
#  'marvin': 2537,
#  'martian': 2535,
#  'helm': 1828,
#  'dog': 1090,
#  'gpcvjibtlm': 1705,
#  'kinda': 2253,
#  'etsy': 1306,
#  'thesheetztweetz': 4242,
#  'serve': 3725,
#  'public': 3297,
#  'hamstring': 1770,
#  'today': 4299,
#  'amazon': 149,
#  'system': 4111,
#  'snigkxdxfp': 3847,
#  'nextspaceflight': 2792,
#  'hoping': 1888,
#  'approval': 202,
#  'flight': 1496,
#  'tomorrow': 4308,
#  'afternoon': 88,
#  'entire': 1270,
#  'collection': 741,
#  'labeling': 2302,
#  'inference': 2023,
#  'surround': 4082,
#  'sqjkn': 3938,
#  'crazy': 870,
#  'turn': 4385,
#  'fsd': 1572,
#  'steadily': 3981,
#  'moving': 2712,
#  'nns': 2820,
#  'camera': 562,
#  'enable': 1247,
#  'superhuman': 4069,
#  'driving': 1127,
#  'naval': 2766,
#  'tyranny': 4410,
#  'road': 3562,
#  'hell': 1826,
#  'paved': 3049,
#  'bad': 328,
#  'intention': 2059,
#  'levine': 2367,
#  'catchy': 601,
#  'au': 270,
#  'myf': 2744,
#  'rn': 3558,
#  'megaconstellati': 2587,
#  'aviation': 304,
#  'intel': 2053,
#  'jetcitystar': 2153,
#  'larrypress': 2316,
#  'sat': 3652,
#  'launched': 2329,
#  'laser': 2317,
#  'link': 2393,
#  'ceofli': 625,
#  'lzm': 2489,
#  'teslagong': 4186,
#  'cleantechnica': 708,
#  'tesmanian': 4209,
#  'ground': 1734,
#  'station': 3977,
#  'pole': 3161,
#  'confusion': 796,
#  'separate': 3717,
#  'number': 2850,
#  'rest': 3500,
#  'surprise': 4079,
#  'hardware': 1786,
#  'software': 3859,
#  'waymo': 4653,
#  'money': 2687,
#  'ricguccio': 3536,
#  'float': 1499,
#  'boringcompany': 472,
#  'fallout': 1396,
#  'themed': 4232,
#  'opening': 2928,
#  'party': 3036,
#  'vega': 4546,
#  'loop': 2438,
#  'happening': 1778,
#  'allowed': 135,
#  'alex': 122,
#  'benton': 383,
#  'tunnel': 4381,
#  'yesterday': 4852,
#  'boy': 481,
#  'tlfouiedfm': 4290,
#  'rideshare': 3542,
#  'offering': 2894,
#  'increased': 2004,
#  'operator': 2933,
#  'seeking': 3704,
#  'reliable': 3465,
#  'affordable': 83,
#  'rid': 3540,
#  'stage': 3955,
#  'landed': 2308,
#  'droneship': 1129,
#  'gwwllixdg': 1755,
#  'liftoff': 2384,
#  'zvm': 4933,
#  'rh': 3532,
#  'codewisdom': 733,
#  'af': 79,
#  'teslascope': 4199,
#  'switching': 4097,
#  'numbering': 2851,
#  'distinguish': 1063,
#  'minor': 2648,
#  'update': 4490,
#  'qmhipv': 3330,
#  'zqs': 4924,
#  'week': 4672,
#  'due': 1144,
#  'unfavorable': 4466,
#  'weather': 4666,
#  'standing': 3961,
#  'continue': 818,
#  'countdown': 850,
#  'seco': 3697,
#  'arstechnica': 231,
#  'sciguyspace': 3673,
#  'depending': 998,
#  'scru': 3682,
#  'gby': 1636,
#  'nacrsn': 2747,
#  'launching': 2330,
#  'wide': 4700,
#  'range': 3382,
#  'customer': 908,
#  'excited': 1336,
#  'qduh': 3322,
#  'gerberkawasaki': 1657,
#  'require': 3489,
#  'fresh': 1561,
#  'water': 4649,
#  'fwxsmo': 1600,
#  'kwtvwm': 2294,
#  'mbn': 2568,
#  'path': 3045,
#  'fully': 1581,
#  'renewable': 3480,
#  'energy': 1257,
#  'solves': 3868,
#  'problem': 3246,
#  'longer': 2435,
#  'chain': 639,
#  'hyd': 1931,
#  'xugrzqijzx': 4823,
#  'detail': 1013,
#  'donating': 1103,
#  'technology': 4156,
#  'eliburton': 1225,
#  'evafoxu': 1319,
#  'janeidyeve': 2130,
#  'austinbarnard': 279,
#  'elonsbrain': 1229,
#  'patterson': 3048,
#  'pretty': 3223,
#  'elonsworld': 1230,
#  'eashanmisra': 1175,
#  'civilization': 697,
#  'gr': 1711,
#  'siar': 3773,
#  'ifvwc': 1960,
#  'laurenrow': 2332,
#  'sarapolak': 3649,
#  'cz': 923,
#  'seanmmitchell': 3691,
#  'vv': 4617,
#  'tthkr': 4376,
#  'teslatino': 4202,
#  'rock': 3572,
#  'eighth': 1207,
#  'zyj': 4937,
#  'zddfql': 4900,
#  'kellyreid': 2234,
#  'rate': 3390,
#  'limiting': 2391,
#  'process': 3248,
#  'cell': 620,
#  'constantly': 807,
#  'changing': 651,
#  'francissuarez': 1548,
#  'cityofmiami': 696,
#  'truck': 4365,
#  'stuck': 4031,
#  'traffic': 4343,
#  'generate': 1648,
#  'megaton': 2589,
#  'toxic': 4331,
#  'particulate': 3033,
#  'jcqiacxjno': 2144,
#  'giant': 1668,
#  'casting': 598,
#  'machine': 2492,
#  'full': 1580,
#  'size': 3804,
#  'chgqmaiyts': 667,
#  'tegmark': 4161,
#  'exceptionally': 1334,
#  'smart': 3832,
#  'manufacturing': 2521,
#  'ultra': 4436,
#  'volume': 4603,
#  'industry': 2019,
#  'food': 1518,
#  'beverage': 394,
#  'medical': 2582,
#  'syrinx': 4110,
#  'toy': 4332,
#  'battery': 349,
#  'fundamental': 1586,
#  'limiter': 2389,
#  'slowing': 3828,
#  'sustainable': 4086,
#  'pr': 3203,
#  'ybabezxcv': 4843,
#  'ferragu': 1440,
#  'question': 3353,
#  'viewed': 4573,
#  'valuable': 4529,
#  'trade': 4340,
#  'glad': 1683,
#  'virgin': 4580,
#  'mrbeastyt': 2716,
#  'whistle': 4690,
#  'cybertruck': 919,
#  'garage': 1621,
#  'awesome': 315,
#  'owenshift': 2988,
#  'signalapp': 3781,
#  'server': 3727,
#  'side': 3777,
#  'code': 730,
#  'wikipedia': 4706,
#  'birthday': 417,
#  'exist': 1343,
#  'watching': 4648,
#  'cobra': 729,
#  'kai': 2217,
#  'superclusterhq': 4064,
#  'ki': 2247,
#  'texas': 4215,
#  'breedlove': 497,
#  'benmezrich': 380,
#  'chuck': 686,
#  'norris': 2828,
#  'divide': 1067,
#  'cerberu': 626,
#  'call': 556,
#  'information': 2025,
#  'labor': 2303,
#  'actuall': 48,
#  'jz': 2210,
#  'zmqgbo': 4918,
#  'monty': 2693,
#  'python': 3316,
#  'ujq': 4424,
#  'iwt': 2113,
#  'twist': 4399,
#  'knife': 2273,
#  'show': 3765,
#  'wise': 4726,
#  'ease': 1174,
#  'swap': 4091,
#  'hour': 1896,
#  'johnkrausphotos': 2180,
#  'slight': 3823,
#  'repair': 3481,
#  'switched': 4096,
#  'nice': 2796,
#  'realomarabdalah': 3423,
#  'school': 3668,
#  'internship': 2070,
#  'college': 742,
#  'skorusark': 3814,
#  'prototype': 3283,
#  'positive': 3176,
#  'excruciating': 1339,
#  'physic': 3106,
#  'splashdown': 3927,
#  'confirmed': 794,
#  'completing': 776,
#  'st': 3949,
#  'resupply': 3507,
#  'return': 3511,
#  'cargo': 584,
#  'resupp': 3506,
#  'detanking': 1014,
#  'inspection': 2039,
#  'hop': 1886,
#  'goal': 1696,
#  'static': 3975,
#  'fire': 1472,
#  'completed': 774,
#  'ruds': 3606,
#  'justpaulinelol': 2205,
#  'happened': 1777,
#  'officialjlipper': 2896,
#  'fair': 1390,
#  'ho': 1870,
#  'ygxas': 4856,
#  'shanty': 3741,
#  'tiktok': 4270,
#  'take': 4119,
#  'actual': 47,
#  'pirate': 3122,
#  'connectdotstoo': 799,
#  'practicing': 3205,
#  'held': 1823,
#  'massive': 2539,
#  'pin': 3119,
#  'fir': 1471,
#  'qtiiwlxxpl': 3345,
#  'promised': 3267,
#  'legalize': 2355,
#  'comedy': 750,
#  'lvladimirovbg': 2483,
#  'steal': 3982,
#  'logo': 2431,
#  'sue': 4050,
#  'appreciated': 200,
#  'star': 3963,
#  'field': 1452,
#  'background': 325,
#  'separation': 3718,
#  'performing': 3077,
#  'departure': 996,
#  'move': 2710,
#  'ohwvnxj': 2905,
#  'suicide': 4052,
#  'double': 1107,
#  'homicide': 1882,
#  'mvwgps': 2740,
#  'uqe': 4501,
#  'hey': 1839,
#  'queen': 3352,
#  'gon': 1699,
#  'na': 2746,
#  'lrqdirbiyd': 2469,
#  'theoldmanpar': 4234,
#  'djsnm': 1072,
#  'machinepix': 2493,
#  'hate': 1792,
#  'physicsj': 3107,
#  'km': 2266,
#  'millisecond': 2639,
#  'faster': 1407,
#  'tkkruvgbth': 4287,
#  'ocy': 2885,
#  'gfryvn': 1662,
#  'iamdevloper': 1941,
#  'bkkeiiicye': 429,
#  ...}
