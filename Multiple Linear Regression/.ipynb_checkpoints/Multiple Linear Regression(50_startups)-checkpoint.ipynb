# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
chetan=pd.read_csv('50_Startups.csv')
chetan.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
chetan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
#check for missing values
chetan.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# # Correlation Matrix

# %%
chetan.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %% [markdown]
# # Scatterplot between variables along with histograms

# %%
#Format the plot background and scatter plots for all the variables
sns.set_style(style='darkgrid')
sns.pairplot(chetan)

# %% [markdown]
# # Preparing a model

# %%
chetan.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
# renaming the columns because it contains the space in between which may cause error in our code.
chetan.rename(columns = {'R&D Spend':'RDS','Administration':'ADM' , 'Marketing Spend':'MS'}, inplace = True)
chetan
# Out:
#           RDS        ADM         MS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
#Build model
import statsmodels.formula.api as smf 
model = smf.ols('Profit ~ RDS+ADM+MS',data=chetan).fit()
model

# %%
#Coefficients
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADM             -0.026816
# MS               0.027228
# dtype: float64

# %%
#t and p-Values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept     7.626218
# RDS          17.846374
# ADM          -0.525507
# MS            1.655077
# dtype: float64
#  Intercept    1.057379e-09
# RDS          2.634968e-22
# ADM          6.017551e-01
# MS           1.047168e-01
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 22 May 2021   Prob (F-statistic):           4.53e-30
# Time:                        18:35:05   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %% [markdown]
# # Simple Linear Regression Models

# %%
ml_v=smf.ols('Profit~RDS',data = chetan).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues) 
ml_v.summary()
# Out:
# Intercept    19.320288
# RDS          29.151139
# dtype: float64
#  Intercept    2.782697e-24
# RDS          3.500322e-32
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Sat, 22 May 2021   Prob (F-statistic):           3.50e-32
# Time:                        18:35:05   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
ml_w=smf.ols('Profit~ADM',data = chetan).fit()  
print(ml_w.tvalues, '\n', ml_w.pvalues)  
ml_w.summary()
# Out:
# Intercept    3.040044
# ADM          1.419493
# dtype: float64
#  Intercept    0.003824
# ADM          0.162217
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Sat, 22 May 2021   Prob (F-statistic):              0.162
# Time:                        18:35:05   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
ml_wv=smf.ols('Profit~MS',data = chetan).fit()  
print(ml_wv.tvalues, '\n', ml_wv.pvalues)  
ml_wv.summary()
# Out:
# Intercept    7.808356
# MS           7.802657
# dtype: float64
#  Intercept    4.294735e-10
# MS           4.381073e-10
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Sat, 22 May 2021   Prob (F-statistic):           4.38e-10
# Time:                        18:35:05   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# profit~ADM is not good, R and R-sqd not good, p value is 0.162 so we leave bcz of insignificant

# %% [markdown]
# # Calculating VIF

# %%
e=smf.ols('MS ~ ADM+RDS',data=chetan).fit()
e.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     MS   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                     31.18
# Date:                Sat, 22 May 2021   Prob (F-statistic):           2.41e-09
# Time:                        18:38:23   Log-Likelihood:                -635.04
# No. Observations:                  50   AIC:                             1276.
# Df Residuals:                      47   BIC:                             1282.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.75e+05   5.24e+04      3.340      0.002    6.96e+04     2.8e+05
# ...

# %%
rsq_RDS = smf.ols('RDS~ADM+MS',data=chetan).fit().rsquared  
vif_RDS = 1/(1-rsq_RDS) 

rsq_ADM = smf.ols('ADM~RDS+MS',data=chetan).fit().rsquared  
vif_ADM = 1/(1-rsq_ADM) 

rsq_MS = smf.ols('MS~RDS+ADM',data=chetan).fit().rsquared  
vif_MS = 1/(1-rsq_MS) 


# Storing vif values in a data frame
d1 = {'Variables':['RDS','ADM','MS'],'VIF':[vif_RDS,vif_ADM,vif_MS]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0       RDS  2.468903
# 1       ADM  1.175091
# 2        MS  2.326773

# %% [markdown]
# # Residual Analysis

# %% [markdown]
# ## Test for Normality of Residuals (Q-Q Plot)

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>10))
# Out:
# [array([ 1,  2,  3,  8, 10, 11, 12, 13, 16, 19, 20, 25, 28, 30, 34, 35, 36,
#         37, 38, 40, 41, 42, 43, 44, 45], dtype=int64)]

# %% [markdown]
# ## Residual Plot for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
model.fittedvalues
# Out:
# 0     192521.252890
# 1     189156.768232
# 2     182147.279096
# 3     173696.700026
# 4     172139.514183
# 5     163580.780571
# 6     158114.096669
# 7     160021.363048
# 8     151741.699699
# 9     154884.684110
# 10    135509.016367
# 11    135573.712961
# 12    129138.054182
# 13    127487.991663
# 14    149548.646335
# 15    146235.159985
# 16    116915.405401
# 17    130192.447208
# 18    129014.226806
# 19    115635.216367
# 20    116639.669231
# 21    117319.451640
# 22    114706.981717
# 23    109996.615221
# 24    113362.966113
# 25    102237.725065
# 26    110600.575350
# 27    114408.071457
# 28    101660.026005
# 29    101794.983452
# 30     99452.372936
# 31     97687.856276
# 32     99001.328985
# 33     97915.007805
# 34     89039.273741
# 35     90511.599568
# 36     75286.174585
# 37     89619.537708
# 38     69697.430648
# 39     83729.011977
# 40     74815.953991
# 41     74802.556239
# 42     70620.411821
# 43     60167.039963
# 44     64611.354916
# ...

# %%
model.resid
# Out:
# 0      -259.422890
# 1      2635.291768
# 2      8903.110904
# 3      9205.289974
# 4     -5951.574183
# 5     -6589.660571
# 6     -1991.586669
# 7     -4268.763048
# 8       470.070301
# 9     -5124.724110
# 10    10612.933633
# 11     8685.687039
# 12    12447.465818
# 13     6819.358337
# 14   -16945.996335
# 15   -16318.119985
# 16    10077.524599
# 17    -4822.077208
# 18    -4747.326806
# 19     7141.643633
# 20     1834.360769
# 21    -6006.431640
# 22    -4354.731717
# 23    -1262.625221
# 24    -4810.926113
# 25     5166.614935
# 26    -4867.035350
# 27    -9399.761457
# 28     1622.353995
# 29     -790.343452
# 30      485.217064
# 31     -204.296276
# 32    -1573.488985
# 33    -1136.087805
# 34     7673.526259
# 35     5967.910432
# 36    15422.015415
# 37      329.602292
# 38    11531.629352
# 39    -2723.251977
# 40     3423.956009
# 41     2996.273761
# 42      878.078179
# 43     9591.940037
# 44      588.975084
# 45    17275.430313
# 46    -6675.456853
# ...

# %% [markdown]
# ## Residual Vs Regressors

# %% [markdown]
# fig = plt.figure(figsize=(15,8))
# fig = sm.graphics.plot_regress_exog(model, "VOL", fig=fig)
# plt.show()
