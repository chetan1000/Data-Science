# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("Computer_Data.csv")

# %%
df
# Out:
#       Unnamed: 0  price  speed    hd  ram  screen   cd multi premium  ads  \
# 0              1   1499     25    80    4      14   no    no     yes   94
# 1              2   1795     33    85    2      14   no    no     yes   94
# 2              3   1595     25   170    4      15   no    no     yes   94
# 3              4   1849     25   170    8      14   no    no      no   94
# 4              5   3295     33   340   16      14   no    no     yes   94
# ...          ...    ...    ...   ...  ...     ...  ...   ...     ...  ...
# 6254        6255   1690    100   528    8      15   no    no     yes   39
# 6255        6256   2223     66   850   16      15  yes   yes     yes   39
# 6256        6257   2654    100  1200   24      15  yes    no     yes   39
# 6257        6258   2195    100   850   16      15  yes    no     yes   39
# 6258        6259   2490    100   850   16      17  yes    no     yes   39
#
#       trend
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi',
#        'premium', 'ads', 'trend'],
#       dtype='object')

# %%
pd.crosstab(df.speed,df.ram)
# Out:
# ram     2    4    8    16  24  32
# speed
# 25      73  320  100   73   0   0
# 33     153  951  586  251  92   0
# 50      73  383  360  129  49   0
# 66      73  492  983  390  84   6
# 75      11   13   54   20  16   8
# 100     11   77  237  133  56   2

# %%
# bar plot between 2 different categories 
pd.crosstab(df.speed,df.ram).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='speed'>

# %%
df["speed"].value_counts()
df.speed.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='speed'>

# %%
plt.scatter(df.speed,df.hd) #scatter plot of two variables

# %%
#import matplotlib.pyplot as plt
# Histogram
plt.hist(df['price'])
# Out:
# (array([ 237., 1554., 1803., 1459.,  850.,  238.,   92.,   18.,    3.,
#            5.]),
#  array([ 949., 1394., 1839., 2284., 2729., 3174., 3619., 4064., 4509.,
#         4954., 5399.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['price'],facecolor ="peru",edgecolor ="blue",bins =5)
# Out:
# (array([1791., 3262., 1088.,  110.,    8.]),
#  array([ 949., 1839., 2729., 3619., 4509., 5399.]),
#  <BarContainer object of 5 artists>)

# %%
#Boxplot
#help(plt.boxplot)
plt.boxplot(df['ads'],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22b3ff8a550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22b3ff8ac10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22b3ff8a1c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22b3ff94310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22b3ff94670>],
#  'means': []}

# %%
plt.boxplot(df['ads'],vert = False);
plt.xlabel('boxplot')
plt.ylabel("ads");

# %%
#Violin Plot
plt.violinplot(df["hd"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x22b40029f70>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x22b3ffb89a0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x22b40042c10>,
#  'cbars': <matplotlib.collections.LineCollection at 0x22b40042f10>}

# %%
DF= pd.read_csv("Cars.csv");DF
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
#Stipplot
sns.stripplot(y= 'MPG', data=DF,jitter=True)
plt.ylabel('MPG ($)')
plt.show()

# %%
#Grouping with stripplot()
sns.stripplot(x='MPG', y='VOL', data=DF)
plt.ylabel('VOL ($)')
plt.show()

# %%
#Swarm plot
sns.swarmplot(x='VOL', y='WT', data=DF)
plt.ylabel('WT ($)')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#Joint plot

sns.jointplot(x= 'MPG', y= 'VOL', data=DF)
plt.show()

# %%
# Density plot
sns.jointplot(x='MPG', y= 'SP', data=DF,kind='kde')
plt.show()

# %%
#pair plot
sns.pairplot(DF)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("Q9_a.csv")

# %%
df
